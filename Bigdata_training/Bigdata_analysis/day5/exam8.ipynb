# %% [markdown]
# ![folium.png](attachment:250fab6f-0051-4e33-af93-9fdb243e9792.png)

# %% [markdown]
# ### Python에서 사용 가능한 라이브러리로서 지도를 다루는 대표적인 라이브러리
# ### leaflet.js 기반으로 지도를 그려주고, 모바일에서도 쓸 수 있을만큼 가볍다.
# https://python-visualization.github.io/folium/

# %%
import folium  # 오류 발생 ModuleNotFoundError: No module named 'folium'

# %%
# 위의 코드셀을 실행시켰을 때 오류가 발생함 folium 을 설치함
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.13.0-py2.py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.5/96.5 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.9 in c:\users\82102\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in c:\users\82102\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from folium) (2.28.1)
# Requirement already satisfied: numpy in c:\users\82102\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from folium) (1.23.2)
# Collecting branca>=0.3.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\82102\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\82102\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->folium) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\82102\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\82102\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->folium) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\82102\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->folium) (2.1.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.13.0
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: C:\Users\82102\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# 서울 지도 그리기
seoul_map = folium.Map(location=[37.55,126.98], zoom_start=12)
display(seoul_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e8f0918e55b54da18b1a6e329fbb61c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e8f0918e55b54da18b1a6e329fbb61c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e8f0918e55b54da18b1a6e329fbb61c = L.map(
#                 &quot;map_7e8f0918e55b54da18b1a6e329fbb61c&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6028d6dc31ae1ab7d6b6a6a7b02f67fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e8f0918e55b54da18b1a6e329fbb61c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Map?
# Out:
# Init signature:
# folium.Map(
#     location=None,
#     width='100%',
#     height='100%',
#     left='0%',
#     top='0%',
#     position='relative',
#     tiles='OpenStreetMap',
#     attr=None,
#     min_zoom=0,
#     max_zoom=18,
#     zoom_start=10,
#     min_lat=-90,
#     max_lat=90,
#     min_lon=-180,
#     max_lon=180,
#     max_bounds=False,
#     crs='EPSG3857',
#     control_scale=False,
#     prefer_canvas=False,
#     no_touch=False,
#     disable_3d=False,
#     png_enabled=False,
#     zoom_control=True,
#     **kwargs,
# )
# Docstring:
# Create a Map with Folium and Leaflet.js
#
# Generate a base map of given width and height with either default
# tilesets or a custom tileset URL. The following tilesets are built-in
# to Folium. Pass any of the following to the "tiles" keyword:
#
#     - "OpenStreetMap"
#     - "Mapbox Bright" (Limited levels of zoom for free tiles)
#     - "Mapbox Control Room" (Limited levels of zoom for free tiles)
#     - "Stamen" (Terrain, Toner, and Watercolor)
#     - "Cloudmade" (Must pass API key)
#     - "Mapbox" (Must pass API key)
#     - "CartoDB" (positron and dark_matter)
#
# You can pass a custom tileset to Folium by passing a Leaflet-style
# URL to the tiles parameter: ``http://{s}.yourtiles.com/{z}/{x}/{y}.png``.
#
# You can find a list of free tile providers here:
# ``http://leaflet-extras.github.io/leaflet-providers/preview/``.
# Be sure to check their terms and conditions and to provide attribution
# with the `attr` keyword.
#
# Parameters
# ----------
# location: tuple or list, default None
#     Latitude and Longitude of Map (Northing, Easting).
# width: pixel int or percentage string (default: '100%')
#     Width of the map.
# height: pixel int or percentage string (default: '100%')
#     Height of the map.
# tiles: str, default 'OpenStreetMap'
#     Map tileset to use. Can choose from a list of built-in tiles,
#     pass a custom URL or pass `None` to create a map without tiles.
#     For more advanced tile layer options, use the `TileLayer` class.
# min_zoom: int, default 0
#     Minimum allowed zoom level for the tile layer that is created.
# max_zoom: int, default 18
#     Maximum allowed zoom level for the tile layer that is created.
# zoom_start: int, default 10
#     Initial zoom level for the map.
# attr: string, default None
#     Map tile attribution; only required if passing custom tile URL.
# crs : str, default 'EPSG3857'
#     Defines coordinate reference systems for projecting geographical points
#     into pixel (screen) coordinates and back.
#     You can use Leaflet's values :
#     * EPSG3857 : The most common CRS for online maps, used by almost all
#     free and commercial tile providers. Uses Spherical Mercator projection.
#     Set in by default in Map's crs option.
#     * EPSG4326 : A common CRS among GIS enthusiasts.
#     Uses simple Equirectangular projection.
#     * EPSG3395 : Rarely used by some commercial tile providers.
#     Uses Elliptical Mercator projection.
#     * Simple : A simple CRS that maps longitude and latitude into
#     x and y directly. May be used for maps of flat surfaces
#     (e.g. game maps). Note that the y axis should still be inverted
#     (going from bottom to top).
# control_scale : bool, default False
#     Whether to add a control scale on the map.
# prefer_canvas : bool, default False
#     Forces Leaflet to use the Canvas back-end (if available) for
#     vector layers instead of SVG. This can increase performance
#     considerably in some cases (e.g. many thousands of circle
#     markers on the map).
# no_touch : bool, default False
#     Forces Leaflet to not use touch events even if it detects them.
# disable_3d : bool, default False
#     Forces Leaflet to not use hardware-accelerated CSS 3D
#     transforms for positioning (which may cause glitches in some
#     rare environments) even if they're supported.
# zoom_control : bool, default True
#     Display zoom controls on the map.
# **kwargs
#     Additional keyword arguments are passed to Leaflets Map class:
#     https://leafletjs.com/reference-1.6.0.html#map
#
# Returns
# -------
# Folium Map Object
#
# Examples
# --------
# >>> m = folium.Map(location=[45.523, -122.675], width=750, height=500)
# >>> m = folium.Map(location=[45.523, -122.675], tiles='cartodb positron')
# >>> m = folium.Map(
# ...    location=[45.523, -122.675],
# ...    zoom_start=2,
# ...    tiles='https://api.mapbox.com/v4/mapbox.streets/{z}/{x}/{y}.png?access_token=mytoken',
# ...    attr='Mapbox attribution'
# ...)
# File:           c:\users\82102\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages\folium\folium.py
# Type:           type
# Subclasses:

# %%
# 서울 지도 만들기
seoul_map2 = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', 
                        zoom_start=12)
seoul_map3 = folium.Map(location=[37.55,126.98], tiles='Stamen Toner', 
                        zoom_start=12)

display(seoul_map2)
display(seoul_map3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a057da02fbf6184b0b4f23681faee367 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a057da02fbf6184b0b4f23681faee367&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a057da02fbf6184b0b4f23681faee367 = L.map(
#                 &quot;map_a057da02fbf6184b0b4f23681faee367&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_377b73a0855a95c98dc940f6ca9e4560 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a057da02fbf6184b0b4f23681faee367);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cff383b93b59fb9e4827ab80649f3c36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cff383b93b59fb9e4827ab80649f3c36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cff383b93b59fb9e4827ab80649f3c36 = L.map(
#                 &quot;map_cff383b93b59fb9e4827ab80649f3c36&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5c72e0ab00fc0261a9f44096edba618 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cff383b93b59fb9e4827ab80649f3c36);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import folium

# 대학교 리스트를 데이터프레임 변환
df = pd.read_excel('./data/서울지역 대학교 위치.xlsx')
df.columns = ['학교명', '위도', '경도']
display(df.head())
# Out:
#             학교명         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
df.shape
# Out:
# (47, 3)

# %%
seoul_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', 
                        zoom_start=11)

# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df.학교명, df.위도, df.경도):
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)
display(seoul_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7d9362ff4abf7a82248ccb9222b31fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7d9362ff4abf7a82248ccb9222b31fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7d9362ff4abf7a82248ccb9222b31fd = L.map(
#                 &quot;map_f7d9362ff4abf7a82248ccb9222b31fd&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6599de25e22a60f16753b3156e3d20a0 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f7d9362ff4abf7a82248ccb9222b31fd);
#
#
#             var marker_d289ba1f24d91ba70762e72604546031 = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_f7d9362ff4abf7a82248ccb9222b31fd);
#
#
#         var popup_e600993da288f1b429569570cf8e336a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0dd6ff124a889bf9cb0f2e4a3b1a9f1c = $(`&lt;div id=&quot;html_0dd6ff124a889bf9cb0f2e4a3b1a9f1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_e600993da288f1b429569570cf8e336a.setContent(html_0dd6ff124a889bf9cb0f2e4a3b1a9f1c);
#
#
#
#         marker_d289ba1f24d91ba70762e72604546031.bindPopup(popup_e600993da288f1b429569570cf8e336a)
#         ;
#
#
#
#
#             var marker_cdd89aaa38da80793064a786e6610155 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_f7d9362ff4abf7a82248ccb9222b31fd);
#
#
#         var popup_aeb84ed7bcb89630b1e6452480a2bb05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b3ef8e88fdf22f911684e8dc1114e85 = $(`&lt;div id=&quot;html_7b3ef8e88fdf22f911684e8dc1114e85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_aeb84ed7bcb89630b1e6452480a2bb05.setContent(html_7b3ef8e88fdf22f911684e8dc1114e85);
#
#
#
#         marker_cdd89aaa38da80793064a786e6610155.bindPopup(popup_aeb84ed7bcb89630b1e6452480a2bb05)
#         ;
#
#
#
#
#             var marker_77eed83cf8809906f6d696901afecbf0 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_f7d9362ff4abf7a82248ccb9222b31fd);
#
#
#         var popup_47a68d6f326068f17c86d60fc2d9cb86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1da0d26c549fe57c7866fe9d54378c28 = $(`&lt;div id=&quot;html_1da0d26c549fe57c7866fe9d54378c28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_47a68d6f326068f17c86d60fc2d9cb86.setContent(html_1da0d26c549fe57c7866fe9d54378c28);
#
#
#
#         marker_77eed83cf8809906f6d696901afecbf0.bindPopup(popup_47a68d6f326068f17c86d60fc2d9cb86)
#         ;
#
#
#
#
#             var marker_95fa0474463b8034587181033707e235 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_f7d9362ff4abf7a82248ccb9222b31fd);
#
#
#         var popup_7927e7cd16768165691494a077904372 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_858e9deb8205c0f5ef1d28800d73d25e = $(`&lt;div id=&quot;html_858e9deb8205c0f5ef1d28800d73d25e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_7927e7cd16768165691494a077904372.setContent(html_858e9deb8205c0f5ef1d28800d73d25e);
#
#
#
#         marker_95fa0474463b8034587181033707e235.bindPopup(popup_7927e7cd16768165691494a077904372)
#         ;
#
#
#
#
#             var marker_c3f3633d256842494c629578ae0a0bc6 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_f7d9362ff4abf7a82248ccb9222b31fd);
#
#
#         var popup_35fd60035ae38b17a580620e3710344e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b839053ad209f466d6af5499116bd497 = $(`&lt;div id=&quot;html_b839053ad209f466d6af5499116bd497&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_35fd60035ae38b17a580620e3710344e.setContent(html_b839053ad209f466d6af5499116bd497);
#
#
#
#         marker_c3f3633d256842494c629578ae0a0bc6.bindPopup(popup_35fd60035ae38b17a580620e3710344e)
#         ;
#
#
#
#
#             var marker_93cdb2ba8fa

# %%
import pandas as pd
import folium

# 대학교 리스트를 데이터프레임 변환
df = pd.read_excel('./data/서울지역 대학교 위치.xlsx')
df.columns = ['학교명', '위도', '경도']
# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', 
                        zoom_start=12)

# 대학교 위치정보를 CircleMarker로 표시
for name, lat, lng in zip(df.학교명, df.위도, df.경도):
    folium.CircleMarker([lat, lng],
                        radius=10,         # 원의 반지름
                        color='brown',         # 원의 둘레 색상
                        fill=True,
                        fill_color='coral',    # 원을 채우는 색
                        fill_opacity=0.7, # 투명도    
                        popup=name
    ).add_to(seoul_map)
    
display(seoul_map)

# 지도를 HTML 파일로 저장하기
seoul_map.save('output/seoul_colleges.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_940eaffd5811d71956db2141d53b58c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_940eaffd5811d71956db2141d53b58c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_940eaffd5811d71956db2141d53b58c7 = L.map(
#                 &quot;map_940eaffd5811d71956db2141d53b58c7&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5f1e62041697ba6f8bc5fc9d8ede4b4 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_940eaffd5811d71956db2141d53b58c7);
#
#
#             var circle_marker_715b236ed11adf86a40e2cbf93f0ae1d = L.circleMarker(
#                 [37.592573, 127.046737],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_940eaffd5811d71956db2141d53b58c7);
#
#
#         var popup_5aa9afda87f5d37d4b29c2f92725f533 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a032faab02ab7be5d1fce156386e005 = $(`&lt;div id=&quot;html_8a032faab02ab7be5d1fce156386e005&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_5aa9afda87f5d37d4b29c2f92725f533.setContent(html_8a032faab02ab7be5d1fce156386e005);
#
#
#
#         circle_marker_715b236ed11adf86a40e2cbf93f0ae1d.bindPopup(popup_5aa9afda87f5d37d4b29c2f92725f533)
#         ;
#
#
#
#
#             var circle_marker_46b3eca0c65fd29b962837813da4c077 = L.circleMarker(
#                 [37.5483449, 126.8547974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_940eaffd5811d71956db2141d53b58c7);
#
#
#         var popup_14e8da9c3914c6d0b30fe05bb0caf2d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f060b932ae48ef379e0be58f64be4b3 = $(`&lt;div id=&quot;html_7f060b932ae48ef379e0be58f64be4b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_14e8da9c3914c6d0b30fe05bb0caf2d7.setContent(html_7f060b932ae48ef379e0be58f64be4b3);
#
#
#
#         circle_marker_46b3eca0c65fd29b962837813da4c077.bindPopup(popup_14e8da9c3914c6d0b30fe05bb0caf2d7)
#         ;
#
#
#
#
#             var circle_marker_e78f0167ecfe89a52ec46a4620058dc2 = L.circleMarker(
#                 [37.5859218, 127.0043275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_940eaffd5811d71956db2141d53b58c7);
#
#
#         var popup_746f59c3a60c9ac8632d203981669fc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ba2391613855752d8a14ce2cb1b59d4 = $(`&lt;div id=&quot;html_4ba2391613855752d8a14ce2cb1b59d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_746f59c3a60c9ac8632d203981669fc8.setContent(html_4ba2391613855752d8a14ce2cb1b59d4);
#
#
#
#         circle_marker_e78f0167ecfe89a52ec46a4620058dc2.bindPopup(popup_746f59c3a60c9ac8632d203981669fc8)
#         ;
#
#
#
#
#             var circle_marker_9728790bc445deb3af18c6dbe28843f5 = L.circleMarker(
#                 [37.4996227, 127.0060653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;

# %%
import pandas as pd
import folium
seoul_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', 
                       zoom_start=12)
tooltip = '클릭하셔용!'

folium.Marker([37.55,126.98], popup='<div style="width:100px;color:green;text-align:center">남산</div>', tooltip=tooltip).add_to(seoul_map)
folium.Marker([37.58,126.975], popup='<div style="width:100px;text-align:center"><b>경복궁</b></div>', tooltip=tooltip).add_to(seoul_map)
display(seoul_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a53d9d0be1e3691935886af8a75dc3de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a53d9d0be1e3691935886af8a75dc3de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a53d9d0be1e3691935886af8a75dc3de = L.map(
#                 &quot;map_a53d9d0be1e3691935886af8a75dc3de&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d814057a5ec07635974fd7cf043b5824 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a53d9d0be1e3691935886af8a75dc3de);
#
#
#             var marker_7b544125340beb6a5f68930ab1b63eae = L.marker(
#                 [37.55, 126.98],
#                 {}
#             ).addTo(map_a53d9d0be1e3691935886af8a75dc3de);
#
#
#         var popup_fe78579c5afc3567fe3d03940f10bf30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e408a83be2292013c19a641e3423cd7f = $(`&lt;div id=&quot;html_e408a83be2292013c19a641e3423cd7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px;color:green;text-align:center&quot;&gt;남산&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_fe78579c5afc3567fe3d03940f10bf30.setContent(html_e408a83be2292013c19a641e3423cd7f);
#
#
#
#         marker_7b544125340beb6a5f68930ab1b63eae.bindPopup(popup_fe78579c5afc3567fe3d03940f10bf30)
#         ;
#
#
#
#
#             marker_7b544125340beb6a5f68930ab1b63eae.bindTooltip(
#                 `&lt;div&gt;
#                      클릭하셔용!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6dfac1428cb92a6a272438f293b93767 = L.marker(
#                 [37.58, 126.975],
#                 {}
#             ).addTo(map_a53d9d0be1e3691935886af8a75dc3de);
#
#
#         var popup_e1b78d35566397dcf86f3312d62487f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dba1ffe4b2e99dab0f3e016fa9556a8e = $(`&lt;div id=&quot;html_dba1ffe4b2e99dab0f3e016fa9556a8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px;text-align:center&quot;&gt;&lt;b&gt;경복궁&lt;/b&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_e1b78d35566397dcf86f3312d62487f2.setContent(html_dba1ffe4b2e99dab0f3e016fa9556a8e);
#
#
#
#         marker_6dfac1428cb92a6a272438f293b93767.bindPopup(popup_e1b78d35566397dcf86f3312d62487f2)
#         ;
#
#
#
#
#             marker_6dfac1428cb92a6a272438f293b93767.bindTooltip(
#                 `&lt;div&gt;
#                      클릭하셔용!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Popup 객체 또는 Marker 객체.add_to(맵객체) 와 맵객체.add_child(Popup 객체 또는 Marker 객체) 동일함

# %%
import pandas as pd
import folium
seoul_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', 
                       zoom_start=12)
tooltip = '클릭하셔용!'

test = folium.Html('<h3>테스트가 잘 되면 좋겠다~~</h3>', script=True)
popup = folium.Popup(test, max_width=300,min_width=300)
icon = folium.map.Icon(color='red', icon='info-sign')

folium.Marker([37.55,126.98], popup = popup, icon=icon, tooltip=tooltip).add_to(seoul_map)
#seoul_map.add_child(folium.Marker([37.55,126.98], popup = popup, icon=icon, tooltip=tooltip))

display(seoul_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d99df0338a5a3bcfcd691ddb08c6847 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d99df0338a5a3bcfcd691ddb08c6847&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d99df0338a5a3bcfcd691ddb08c6847 = L.map(
#                 &quot;map_8d99df0338a5a3bcfcd691ddb08c6847&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77f5da0d001e5324fb34354b660260d5 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8d99df0338a5a3bcfcd691ddb08c6847);
#
#
#             var marker_35491b7e662ab80982727539f3fa98c7 = L.marker(
#                 [37.55, 126.98],
#                 {}
#             ).addTo(map_8d99df0338a5a3bcfcd691ddb08c6847);
#
#
#             var icon_3a5d5da3568edabaf9a91f734ec0a50b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_35491b7e662ab80982727539f3fa98c7.setIcon(icon_3a5d5da3568edabaf9a91f734ec0a50b);
#
#
#         var popup_1d2bd4799836e0ae6ee3075e89fc5d8a = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_bea7aaff915122dba82215243921fb41 = $(`&lt;div id=&quot;html_bea7aaff915122dba82215243921fb41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3&gt;테스트가 잘 되면 좋겠다~~&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_1d2bd4799836e0ae6ee3075e89fc5d8a.setContent(html_bea7aaff915122dba82215243921fb41);
#
#
#
#         marker_35491b7e662ab80982727539f3fa98c7.bindPopup(popup_1d2bd4799836e0ae6ee3075e89fc5d8a)
#         ;
#
#
#
#
#             marker_35491b7e662ab80982727539f3fa98c7.bindTooltip(
#                 `&lt;div&gt;
#                      클릭하셔용!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import folium
seoul_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', 
                       zoom_start=12)
seoul_map.add_child(folium.LatLngPopup())
#folium.LatLngPopup().add_to(seoul_map)
display(seoul_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfb3a95e96f2c399358ba77462476a12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfb3a95e96f2c399358ba77462476a12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfb3a95e96f2c399358ba77462476a12 = L.map(
#                 &quot;map_bfb3a95e96f2c399358ba77462476a12&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c1d5d98d12a9d61da8c99891e3cc79f = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bfb3a95e96f2c399358ba77462476a12);
#
#
#                 var lat_lng_popup_880146e1a2636980d4729cafa20fd9e9 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_880146e1a2636980d4729cafa20fd9e9
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_bfb3a95e96f2c399358ba77462476a12);
#                     }
#                 map_bfb3a95e96f2c399358ba77462476a12.on(&#x27;click&#x27;, latLngPop);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import folium
seoul_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', 
                       zoom_start=12)
folium.Marker(
    [37.55,126.98],
    popup='남산'
).add_to(seoul_map)

seoul_map.add_child(folium.ClickForMarker(popup='내가 찍은 마커!!'))

display(seoul_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c198d6bb171a0d5516fca9d2b0bc5620 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c198d6bb171a0d5516fca9d2b0bc5620&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c198d6bb171a0d5516fca9d2b0bc5620 = L.map(
#                 &quot;map_c198d6bb171a0d5516fca9d2b0bc5620&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c9e96041b7de93fb841f565e09da3ec = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c198d6bb171a0d5516fca9d2b0bc5620);
#
#
#             var marker_2b1e214411f8c8303c71516b7dee1d95 = L.marker(
#                 [37.55, 126.98],
#                 {}
#             ).addTo(map_c198d6bb171a0d5516fca9d2b0bc5620);
#
#
#         var popup_4603634e9c3f0001430715f5033db973 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f05f2983c71115eea2fedfcef3e1b9d = $(`&lt;div id=&quot;html_1f05f2983c71115eea2fedfcef3e1b9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;남산&lt;/div&gt;`)[0];
#                 popup_4603634e9c3f0001430715f5033db973.setContent(html_1f05f2983c71115eea2fedfcef3e1b9d);
#
#
#
#         marker_2b1e214411f8c8303c71516b7dee1d95.bindPopup(popup_4603634e9c3f0001430715f5033db973)
#         ;
#
#
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_c198d6bb171a0d5516fca9d2b0bc5620);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_c198d6bb171a0d5516fca9d2b0bc5620.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(&quot;내가 찍은 마커!!&quot;);
#                     };
#                 map_c198d6bb171a0d5516fca9d2b0bc5620.on(&#x27;click&#x27;, newMarker);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

m = folium.Map(location=[37.55,126.99], zoom_start=15)

folium.CircleMarker(
  [37.55,126.99],
  radius=100,
  color='#00ff00',
  fill_color='#ff000099',
  popup='여기가 남산이에요'
).add_to(m)

display(m)

#m.save('output/map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_214bfeae716b71b0e9878aa32822044f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_214bfeae716b71b0e9878aa32822044f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_214bfeae716b71b0e9878aa32822044f = L.map(
#                 &quot;map_214bfeae716b71b0e9878aa32822044f&quot;,
#                 {
#                     center: [37.55, 126.99],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f726d359d4a6f5a392ef1c34a8caa480 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_214bfeae716b71b0e9878aa32822044f);
#
#
#             var circle_marker_d8e844627a1454dad1bcd7b38b4dd9d8 = L.circleMarker(
#                 [37.55, 126.99],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00ff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff000099&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_214bfeae716b71b0e9878aa32822044f);
#
#
#         var popup_b951ac88927e91dbe6dfaa03d464355b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_354b5ea7ac8e3b41be643824264b12a8 = $(`&lt;div id=&quot;html_354b5ea7ac8e3b41be643824264b12a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;여기가 남산이에요&lt;/div&gt;`)[0];
#                 popup_b951ac88927e91dbe6dfaa03d464355b.setContent(html_354b5ea7ac8e3b41be643824264b12a8);
#
#
#
#         circle_marker_d8e844627a1454dad1bcd7b38b4dd9d8.bindPopup(popup_b951ac88927e91dbe6dfaa03d464355b)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

m = folium.Map(location=[37.55,126.99], zoom_start=15)
html_content = folium.Html('<h3>여기가 <span style="color:red">남산</span>이에요~~</h3>', script=True)
popup_content = folium.Popup(html_content, max_width=300,min_width=300)

folium.CircleMarker(
  [37.55,126.99],
  radius=100,
  color='#00ff00',
  fill_color='#ff000099',
  popup=popup_content
).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a93e950cc08160e3467ffba77d3a3157 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a93e950cc08160e3467ffba77d3a3157&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a93e950cc08160e3467ffba77d3a3157 = L.map(
#                 &quot;map_a93e950cc08160e3467ffba77d3a3157&quot;,
#                 {
#                     center: [37.55, 126.99],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c3a3e1ff7d92d4894803de8ab9a606c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a93e950cc08160e3467ffba77d3a3157);
#
#
#             var circle_marker_1a941d59ea6b0a86628cf6ad047210fc = L.circleMarker(
#                 [37.55, 126.99],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00ff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff000099&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a93e950cc08160e3467ffba77d3a3157);
#
#
#         var popup_1396515f23d95feb77e7350a3936d61e = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_d2c1d8906e7d499fe01690e16411f3a0 = $(`&lt;div id=&quot;html_d2c1d8906e7d499fe01690e16411f3a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3&gt;여기가 &lt;span style=&quot;color:red&quot;&gt;남산&lt;/span&gt;이에요~~&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_1396515f23d95feb77e7350a3936d61e.setContent(html_d2c1d8906e7d499fe01690e16411f3a0);
#
#
#
#         circle_marker_1a941d59ea6b0a86628cf6ad047210fc.bindPopup(popup_1396515f23d95feb77e7350a3936d61e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('output/map.html')

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:red'>단계구분도(Choropleth map)</span>
#
# ### 각기 다른 음영이나 색상 또는 값으로 각 지역과 관련된 데이터를 표현한 지도
#
# #### 지도 데이터 파일 (.geojson, .json) - 지역에 대한 경계 정보를 제공
# #### 시각화 하고자 하는 데이터 파일 (.csv 등) - 지역별로 표현하고자 하는 데이터를 제공
#
# __Choropleth와 같은 레이어를 만들 때 위의 이 두 데이터를 파라미터로 넘겨줘야 하는데 데이터들은 각자 다른 파일에 있으므로,__
# __시각화할 데이터를 지도에 얹으려면 두 파일의 데이터들을 매핑해야 한다.__

# %% [markdown]
# #### folium.Choropleth(
# ####    geo_data = "지도 데이터 파일(.geojson(또는 .json), geopandas.DataFrame)에 대한 딕셔너리 객체"
# ####    data = "지도위에 시각화 하고자 하는 데이터파일. (pandas.DataFrame)"
# ####    columns = [지도 데이터와 매핑할 인덱스 또는 열, 시각화 하려는 값을 가진 열],
# ####    key_on = "지도 데이터 파일에서 데이터 파일과 매핑할 값 feature.properties.xxx",
# ####    fill_color = "시각화에 쓰일 칼라맵",[fill_opacity=, line_opacity= ,]
# #### ).add_to(m)

# %%
import pandas as pd
import folium
import json

# 경기도 인구변화 데이터를 불러와서 데이터프레임으로 변환
file_path = 'data/경기도인구데이터.xlsx'
df = pd.read_excel(file_path, index_col='구분')  
df.columns = df.columns.map(str)
display(df.head())
# Out:
#           2007    2008    2009    2010    2011    2012    2013    2014  \
# 구분
# 수원시장안구  287474  285803  290798  293692  290999  291757  300908  301196
# 수원시권선구  310553  308177  304097  306783  321176  332633  331773  339835
# 수원시팔달구  216945  213235  219833  216503  209772  206794  204805  203479
# 수원시영통구  252730  260210  258421  260557  266542  289074  310671  329718
# 성남시수정구  256744  248452  242161  241070  236123  233997  228167  223539
#
#           2015    2016    2017
# 구분
# 수원시장안구  299016  296479  293828
# 수원시권선구  351053  358393  365653
# 수원시팔달구  199180  198515  193311
# 수원시영통구  335375  340654  349836
# 성남시수정구  219531  232841  236932

# %%
sr = df['2017']
print(sr)
# Out:
# 구분
# 수원시장안구     293828
# 수원시권선구     365653
# 수원시팔달구     193311
# 수원시영통구     349836
# 성남시수정구     236932
# 성남시중원구     230366
# 성남시분당구     500212
# 의정부시       441584
# 안양시만안구     254977
# 안양시동안구     332787
# 부천시원미구     442898
# 부천시소사구     222016
# 부천시오정구     184073
# 광명시        332790
# 평택시        481530
# 동두천시        97071
# 안산시상록구     370744
# 안산시단원구     306966
# 고양시덕양구     448684
# 고양시일산동구    293673
# 고양시일산서구    299626
# 과천시         57527
# 구리시        200042
# 남양주시       665321
# 오산시        213437
# 시흥시        419664
# 군포시        281205
# 의왕시        155767
# 하남시        232487
# 용인시처인구     231553
# 용인시기흥구     419429
# 용인시수지구     353099
# 파주시        437848
# 이천시        213142
# 안성시        182786
# 김포시        392092
# 화성시        691086
# 광주시        345947
# 양주시        212146
# 포천시        152925
# 여주시        111984
# 연천군         45431
# 가평군         62973
# 양평군        115105
# Name: 2017, dtype: int64

# %%
print(sr.index)
# Out:
# Index(['수원시장안구', '수원시권선구', '수원시팔달구', '수원시영통구', '성남시수정구', '성남시중원구', '성남시분당구',
#        '의정부시', '안양시만안구', '안양시동안구', '부천시원미구', '부천시소사구', '부천시오정구', '광명시', '평택시',
#        '동두천시', '안산시상록구', '안산시단원구', '고양시덕양구', '고양시일산동구', '고양시일산서구', '과천시',
#        '구리시', '남양주시', '오산시', '시흥시', '군포시', '의왕시', '하남시', '용인시처인구', '용인시기흥구',
#        '용인시수지구', '파주시', '이천시', '안성시', '김포시', '화성시', '광주시', '양주시', '포천시', '여주시',
#        '연천군', '가평군', '양평군'],
#       dtype='object', name='구분')

# %%
# 경기도 시군구 경계 정보를 가진 geo-json 파일 불러오기
geo_path = 'data/경기도행정구역경계.json'
geo_data = json.load(open(geo_path, encoding='utf-8'))


# 경기도 지도 만들기
g_map = folium.Map(location=[37.5502,126.982], 
                   tiles='Stamen Terrain', zoom_start=9)

# Choropleth 클래스로 단계구분도 표시하기
folium.Choropleth(geo_data=geo_data,    # 지도 경계
                  data = sr,      # 표시하려는 데이터
                  columns = [sr.index, sr],  # 열 지정
                  fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
                  threshold_scale=[10000, 100000, 300000, 500000, 700000],              
                  key_on='feature.properties.name',
                  highlight=True  
                 ).add_to(g_map)

display(g_map)
# 지도를 HTML 파일로 저장하기
#g_map.save('output/gyonggi_population_' + year + '.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b6035a250045adcc4c0b9988a621f2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b6035a250045adcc4c0b9988a621f2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b6035a250045adcc4c0b9988a621f2b = L.map(
#                 &quot;map_6b6035a250045adcc4c0b9988a621f2b&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d80441ea91e709aaea04d83b409c78a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b6035a250045adcc4c0b9988a621f2b);
#
#
#             var choropleth_8eeb923a045ffbba69c6f2b375442746 = L.featureGroup(
#                 {}
#             ).addTo(map_6b6035a250045adcc4c0b9988a621f2b);
#
#
#         function geo_json_c730e371d71a449da68338db8d9c1446_styler(feature) {
#             switch(feature.properties.code) {
#                 case 31370: case 31350: case 31110: case 31080:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31250: case 31230: case 31200: case 31193: case 31192: case 31150: case 31101: case 31092: case 31091: case 31070: case 31060: case 31051: case 31042: case 31030: case 31014: case 31012:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31240: case 31130: case 31023:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e31a1c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_c730e371d71a449da68338db8d9c1446_highlighter(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8999999999999999, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_c730e371d71a449da68338db8d9c1446_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_c730e371d71a449da68338db8d9c1446.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c730e371d71a449da68338db8d9c1446_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c730e371d71a449da68338db8d9c1446 = L.geoJson(null, {
#                 onEachFeature: geo_json_c730e371d71a449da68338db8d9c1446_onEachFeature,
#
#                 style: geo_json_c730e371d71a449da68338db8d9c1446_styler,
#         });
#
#         function geo_json_c730e371d71a449da68338db8d9c1446_add (data) {
#             geo_json_c730e371d71a449da68338db8d9c1446
#                 .addData(data)
#                 .addTo(choropleth_8eeb923a045ffbba69c6f2b375442746);
#         }
#             geo_json_c730e371d71a449da68338db8d9c1446_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.57290963929243, 37.61087369350498], [127.56366973908277, 37.5842624297699], [127.52226606559191, 37.5828628697518], [127.50048767007603, 37.569036373178626], [127.47687473909174, 37.574448241913856], [127.47565866803647, 37.60512112601634], [127.44699730711024, 37.64497584741164], [127.4272349102434, 37.66284420898682], [127.40156700708162, 37.64806970784708], [127.3732642199939, 37.6453987554284], [127.3542931884407, 37.6250006376975], [127.34360057873045, 37.588997440929354], [127.31002843450217, 37.53523876142835], [127.30923294884336, 37.5135706079458], [127.32809611134748, 37.53133849534739], [127.3663244453597, 37.52716845880826], [127.38286320755414, 37.50147517965334], [127.39046783039153, 37.47413422098595], [127.37490698722792, 37.455072688441305], [127.391744

# %%
# 튤팁처리 추가
g_map = folium.Map(location=[37.5502,126.982], 
                   tiles='Stamen Terrain', zoom_start=9)

# Choropleth 클래스로 단계구분도 표시하기
fmap=folium.Choropleth(geo_data=geo_data,    # 지도 경계
                 data = sr,      # 표시하려는 데이터
                 columns = [sr.index, sr],  # 열 지정
                 fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
                 threshold_scale=[10000, 100000, 300000, 500000, 700000],               
                 key_on='feature.properties.name',
                 highlight=True                 
                 ).add_to(g_map)
fmap.geojson.zoom_on_click = False
fmap.geojson.add_child(
     folium.features.GeoJsonTooltip(['name'],labels=False)
)

display(g_map)
# 지도를 HTML 파일로 저장하기
year = '2017'
g_map.save('output/gyonggi_population_' + year + '_2.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_457ab7f21072268bda74c9c35cf1568e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_457ab7f21072268bda74c9c35cf1568e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_457ab7f21072268bda74c9c35cf1568e = L.map(
#                 &quot;map_457ab7f21072268bda74c9c35cf1568e&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33d94257ef12ba471b3fe44bede3e305 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_457ab7f21072268bda74c9c35cf1568e);
#
#
#             var choropleth_94896af3d6191c7bc7010c92739e20b4 = L.featureGroup(
#                 {}
#             ).addTo(map_457ab7f21072268bda74c9c35cf1568e);
#
#
#         function geo_json_eafc853d66587c8c627cb044ba20c5ca_styler(feature) {
#             switch(feature.properties.code) {
#                 case 31370: case 31350: case 31110: case 31080:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31250: case 31230: case 31200: case 31193: case 31192: case 31150: case 31101: case 31092: case 31091: case 31070: case 31060: case 31051: case 31042: case 31030: case 31014: case 31012:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31240: case 31130: case 31023:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e31a1c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_eafc853d66587c8c627cb044ba20c5ca_highlighter(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8999999999999999, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_eafc853d66587c8c627cb044ba20c5ca_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_eafc853d66587c8c627cb044ba20c5ca.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_eafc853d66587c8c627cb044ba20c5ca_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_eafc853d66587c8c627cb044ba20c5ca = L.geoJson(null, {
#                 onEachFeature: geo_json_eafc853d66587c8c627cb044ba20c5ca_onEachFeature,
#
#                 style: geo_json_eafc853d66587c8c627cb044ba20c5ca_styler,
#         });
#
#         function geo_json_eafc853d66587c8c627cb044ba20c5ca_add (data) {
#             geo_json_eafc853d66587c8c627cb044ba20c5ca
#                 .addData(data)
#                 .addTo(choropleth_94896af3d6191c7bc7010c92739e20b4);
#         }
#             geo_json_eafc853d66587c8c627cb044ba20c5ca_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.57290963929243, 37.61087369350498], [127.56366973908277, 37.5842624297699], [127.52226606559191, 37.5828628697518], [127.50048767007603, 37.569036373178626], [127.47687473909174, 37.574448241913856], [127.47565866803647, 37.60512112601634

# %%
# 경기도 지도 만들기
g_map = folium.Map(location=[37.5502,126.982], 
                   tiles='Stamen Terrain', zoom_start=9)

# Choropleth 클래스로 단계구분도 표시하기
fmap=folium.Choropleth(geo_data=geo_data,    # 지도 경계
                 data = sr,      # 표시하려는 데이터
                 columns = [sr.index, sr],  # 열 지정
                 fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
                 threshold_scale=[10000, 100000, 300000, 500000, 700000],               
                 key_on='feature.properties.name',
                 highlight=True                 
                 ).add_to(g_map)
fmap.geojson.zoom_on_click = False
fmap.geojson.add_child(
    folium.features.GeoJsonPopup(['name'],labels=False)
)

display(g_map)
# 지도를 HTML 파일로 저장하기
year = '2017'
g_map.save('output/gyonggi_population_' + year + '_3.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77d652369eb03b0740fe36c5fe8345b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77d652369eb03b0740fe36c5fe8345b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77d652369eb03b0740fe36c5fe8345b8 = L.map(
#                 &quot;map_77d652369eb03b0740fe36c5fe8345b8&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3be684ea06bf0f09cc4082840b2006b5 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77d652369eb03b0740fe36c5fe8345b8);
#
#
#             var choropleth_856974157da421de1bb133faf4f20331 = L.featureGroup(
#                 {}
#             ).addTo(map_77d652369eb03b0740fe36c5fe8345b8);
#
#
#         function geo_json_e5977994401eb04656147b85bba6dc7a_styler(feature) {
#             switch(feature.properties.code) {
#                 case 31370: case 31350: case 31110: case 31080:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31250: case 31230: case 31200: case 31193: case 31192: case 31150: case 31101: case 31092: case 31091: case 31070: case 31060: case 31051: case 31042: case 31030: case 31014: case 31012:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31240: case 31130: case 31023:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e31a1c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_e5977994401eb04656147b85bba6dc7a_highlighter(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8999999999999999, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_e5977994401eb04656147b85bba6dc7a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_e5977994401eb04656147b85bba6dc7a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e5977994401eb04656147b85bba6dc7a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e5977994401eb04656147b85bba6dc7a = L.geoJson(null, {
#                 onEachFeature: geo_json_e5977994401eb04656147b85bba6dc7a_onEachFeature,
#
#                 style: geo_json_e5977994401eb04656147b85bba6dc7a_styler,
#         });
#
#         function geo_json_e5977994401eb04656147b85bba6dc7a_add (data) {
#             geo_json_e5977994401eb04656147b85bba6dc7a
#                 .addData(data)
#                 .addTo(choropleth_856974157da421de1bb133faf4f20331);
#         }
#             geo_json_e5977994401eb04656147b85bba6dc7a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.57290963929243, 37.61087369350498], [127.56366973908277, 37.5842624297699], [127.52226606559191, 37.5828628697518], [127.50048767007603, 37.569036373178626], [127.47687473909174, 37.574448241913856], [127.47565866803647, 37.605121126

# %%
folium.Choropleth?
# Out:
# Init signature:
# folium.Choropleth(
#     geo_data,
#     data=None,
#     columns=None,
#     key_on=None,
#     bins=6,
#     fill_color=None,
#     nan_fill_color='black',
#     fill_opacity=0.6,
#     nan_fill_opacity=None,
#     line_color='black',
#     line_weight=1,
#     line_opacity=1,
#     name=None,
#     legend_name='',
#     overlay=True,
#     control=True,
#     show=True,
#     topojson=None,
#     smooth_factor=None,
#     highlight=None,
#     **kwargs,
# )
# Docstring:
# Apply a GeoJSON overlay to the map.
#
# Plot a GeoJSON overlay on the base map. There is no requirement
# to bind data (passing just a GeoJSON plots a single-color overlay),
# but there is a data binding option to map your columnar data to
# different feature objects with a color scale.
#
# If data is passed as a Pandas DataFrame, the "columns" and "key-on"
# keywords must be included, the first to indicate which DataFrame
# columns to use, the second to indicate the layer in the GeoJSON
# on which to key the data. The 'columns' keyword does not need to be
# passed for a Pandas series.
#
# Colors are generated from color brewer (http://colorbrewer2.org/)
# sequential palettes. By default, linear binning is used between
# the min and the max of the values. Custom binning can be achieved
# with the `bins` parameter.
#
# TopoJSONs can be passed as "geo_data", but the "topojson" keyword must
# also be passed with the reference to the topojson objects to convert.
# See the topojson.feature method in the TopoJSON API reference:
# https://github.com/topojson/topojson/wiki/API-Reference
#
#
# Parameters
# ----------
# geo_data: string/object
#     URL, file path, or data (json, dict, geopandas, etc) to your GeoJSON
#     geometries
# data: Pandas DataFrame or Series, default None
#     Data to bind to the GeoJSON.
# columns: dict or tuple, default None
#     If the data is a Pandas DataFrame, the columns of data to be bound.
#     Must pass column 1 as the key, and column 2 the values.
# key_on: string, default None
#     Variable in the `geo_data` GeoJSON file to bind the data to. Must
#     start with 'feature' and be in JavaScript objection notation.
#     Ex: 'feature.id' or 'feature.properties.statename'.
# bins: int or sequence of scalars or str, default 6
#     If `bins` is an int, it defines the number of equal-width
#     bins between the min and the max of the values.
#     If `bins` is a sequence, it directly defines the bin edges.
#     For more information on this parameter, have a look at
#     numpy.histogram function.
# fill_color: string, optional
#     Area fill color, defaults to blue. Can pass a hex code, color name,
#     or if you are binding data, one of the following color brewer palettes:
#     'BuGn', 'BuPu', 'GnBu', 'OrRd', 'PuBu', 'PuBuGn', 'PuRd', 'RdPu',
#     'YlGn', 'YlGnBu', 'YlOrBr', and 'YlOrRd'.
# nan_fill_color: string, default 'black'
#     Area fill color for nan or missing values.
#     Can pass a hex code, color name.
# fill_opacity: float, default 0.6
#     Area fill opacity, range 0-1.
# nan_fill_opacity: float, default fill_opacity
#     Area fill opacity for nan or missing values, range 0-1.
# line_color: string, default 'black'
#     GeoJSON geopath line color.
# line_weight: int, default 1
#     GeoJSON geopath line weight.
# line_opacity: float, default 1
#     GeoJSON geopath line opacity, range 0-1.
# legend_name: string, default empty string
#     Title for data legend.
# topojson: string, default None
#     If using a TopoJSON, passing "objects.yourfeature" to the topojson
#     keyword argument will enable conversion to GeoJSON.
# smooth_factor: float, default None
#     How much to simplify the polyline on each zoom level. More means
#     better performance and smoother look, and less means more accurate
#     representation. Leaflet defaults to 1.0.
# highlight: boolean, default False
#     Enable highlight functionality when hovering over a GeoJSON area.
# name : string, optional
#     The name of the layer, as it will appear in LayerControls
# overlay : bool, default True
#     Adds the layer as an optional overlay (True) or the base layer (False).
# control : bool, default True
#     Whether the Layer will be included in LayerControls.
# show: bool, default True
#     Whether the layer will be shown on opening (only for overlays).
#
# Returns
# -------
# GeoJSON data layer in obj.template_vars
#
# Examples
# --------
# >>> Choropleth(geo_data='us-states.json', line_color='blue',
# ...            line_weight=3)
# >>> Choropleth(geo_data='geo.json', data=df,
# ...            columns=['Data 1', 'Data 2'],
# ...            key_on='feature.properties.myvalue',
# ...            fill_color='PuBu',
# ...            bins=[0, 20, 30, 40, 50, 60])
# >>> Choropleth(geo_data='countries.json',
# ...            topojson='objects.countries')
# >>> Choropleth(geo_data='geo.json', data=df,
# ...            columns=['Data 1', 'Data 2'],
# ...            key_on='feature.properties.myvalue',
# ...            fill_color='PuBu',
# ...            bins=[0, 20, 30, 40, 50, 60],
# ...            highlight=True)
# File:           c:\users\82102\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages\folium\features.py
# Type:           type
# Subclasses:

# %%
pop = pd.read_csv("./data/cctv_seoul.csv")
pop.head()
# Out:
#     구별  CCTV수       인구수       한국인      외국인      고령자
# 0  강남구   2780  570500.0  565550.0   4950.0  63167.0
# 1  강동구    773  453233.0  449019.0   4214.0  54622.0
# 2  강북구    748  330192.0  326686.0   3506.0  54813.0
# 3  강서구    884  603772.0  597248.0   6524.0  72548.0
# 4  관악구   1496  525515.0  507203.0  18312.0  68082.0

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구별      25 non-null     object
#  1   CCTV수   25 non-null     int64
#  2   인구수     25 non-null     float64
#  3   한국인     25 non-null     float64
#  4   외국인     25 non-null     float64
#  5   고령자     25 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage:
styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;\uc885\ub85c\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc1a1\ud30c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_4287e77712b2ce3fc10d3eadeb276e85_highlighter(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_4287e77712b2ce3fc10d3eadeb276e85_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_4287e77712b2ce3fc10d3eadeb276e85.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4287e77712b2ce3fc10d3eadeb276e85_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4287e77712b2ce3fc10d3eadeb276e85 = L.geoJson(null, {
#                 onEachFeature: geo_json_4287e77712b2ce3fc10d3eadeb276e85_onEachFeature,
#
#                 style: geo_json_4287e77712b2ce3fc10d3eadeb276e85_styler,
#         });
#
#         function geo_json_4287e77712b2ce3fc10d3eadeb276e85_add (data) {
#             geo_json_4287e77712b2ce3fc10d3ead

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
fmap=folium.Choropleth(geo_data = geo_str,
               data = pop,
               columns = ['구별', '고령자'],
               fill_color = 'PuOr', line_opacity=0.3,
               key_on='feature.properties.name',
               highlight=True).add_to(map)
fmap.geojson.zoom_on_click = False
fmap.geojson.add_child(
    folium.features.GeoJsonTooltip(['name'],labels=False)
)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71c61331a8a5197b3869e6701b0da38d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71c61331a8a5197b3869e6701b0da38d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71c61331a8a5197b3869e6701b0da38d = L.map(
#                 &quot;map_71c61331a8a5197b3869e6701b0da38d&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de441424e5bbbaf095adbef2e0774942 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_71c61331a8a5197b3869e6701b0da38d);
#
#
#             var choropleth_27797e0d7161b90b6668bbf3fec6c667 = L.featureGroup(
#                 {}
#             ).addTo(map_71c61331a8a5197b3869e6701b0da38d);
#
#
#         function geo_json_d3d4ea026da9339723e1d9071c67f625_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;\uc885\ub85c\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b35806&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1a340&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee0b6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#998ec3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc1a1\ud30c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#542788&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d8daeb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_d3d4ea026da9339723e1d9071c67f625_highlighter(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_d3d4ea026da9339723e1d9071c67f625_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_d3d4ea026da9339723e1d9071c67f625.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d3d4ea026da9339723e1d9071c67f625_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d3d4ea026da9339723e1d9071c67f625 = L.geoJson(null, {
#                 onEachFeature: geo_json_d3d4ea026da9339723e1d9071c67f625_onEachFeature,
#
#                 style: geo_json_d3d4ea026da9339723e1d9071c67f625_styler,
#         });
#
#         function geo_json_d3d4ea026da9339723e1d9071c67f625_add (data) {
#             geo_json_d3d4ea026da9339723e1d9071c67f625
#                 .addData(data)

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
fmap=folium.Choropleth(geo_data = geo_str,
               data = pop,
               columns = ['구별', '외국인'],
               fill_color = 'Reds', line_opacity=0.3,
               key_on='feature.properties.name',
               highlight=True).add_to(map)
fmap.geojson.zoom_on_click = False
fmap.geojson.add_child(
    folium.features.GeoJsonTooltip(['name'],labels=False)
)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6516891e660c239fe9b063ae572161e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6516891e660c239fe9b063ae572161e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6516891e660c239fe9b063ae572161e = L.map(
#                 &quot;map_a6516891e660c239fe9b063ae572161e&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20b3ac046a05e6fbc972031333774288 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6516891e660c239fe9b063ae572161e);
#
#
#             var choropleth_084bf5cda9daee1ecac9c4e19ff3e1b4 = L.featureGroup(
#                 {}
#             ).addTo(map_a6516891e660c239fe9b063ae572161e);
#
#
#         function geo_json_196d61dfb8a3d328afa4539f7b55a98e_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;\uc885\ub85c\uad6c&quot;: case &quot;\uc911\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fcbba1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc9272&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a50f15&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fb6a4a&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee5d9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_196d61dfb8a3d328afa4539f7b55a98e_highlighter(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_196d61dfb8a3d328afa4539f7b55a98e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_196d61dfb8a3d328afa4539f7b55a98e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_196d61dfb8a3d328afa4539f7b55a98e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_196d61dfb8a3d328afa4539f7b55a98e = L.geoJson(null, {
#                 onEachFeature: geo_json_196d61dfb8a3d328afa4539f7b55a98e_onEachFeature,
#
#                 style: geo_json_196d61dfb8a3d328afa4539f7b55a98e_styler,
#         });
#
#         function geo_json_196d61dfb8a3d328afa4539f7b55a98e_add (data) {
#             geo_json_196d61dfb8a3d328afa4539f7b55a98e
#                 .addData(data)
#                 .addTo(choropleth_084bf5cda9daee1ecac9c4e19ff3e1b4);
#         }
#             geo_json_196d61dfb8a3d328afa4539f7b55a98e_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
fmap=folium.Choropleth(geo_data = geo_str,
               data = pop, line_opacity=0.3,
               columns = ['구별', 'CCTV수'],
               fill_color = 'Blues',
               key_on='feature.properties.name',
               highlight=True).add_to(map)
fmap.geojson.zoom_on_click = False
fmap.geojson.add_child(
    folium.features.GeoJsonTooltip(['name'],labels=False)
)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f412706911c25240595d2a3991e422b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f412706911c25240595d2a3991e422b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f412706911c25240595d2a3991e422b = L.map(
#                 &quot;map_6f412706911c25240595d2a3991e422b&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6dd9d6cf420a336b4d591ad7266c61b1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f412706911c25240595d2a3991e422b);
#
#
#             var choropleth_af1e31f71a325d718be1a7d78c4e9f59 = L.featureGroup(
#                 {}
#             ).addTo(map_6f412706911c25240595d2a3991e422b);
#
#
#         function geo_json_63667abbc54330dad22f6d1f78afb1e0_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;\uc885\ub85c\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uc591\ucc9c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_63667abbc54330dad22f6d1f78afb1e0_highlighter(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_63667abbc54330dad22f6d1f78afb1e0_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_63667abbc54330dad22f6d1f78afb1e0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_63667abbc54330dad22f6d1f78afb1e0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_63667abbc54330dad22f6d1f78afb1e0 = L.geoJson(null, {
#                 onEachFeature: geo_json_63667abbc54330dad22f6d1f78afb1e0_onEachFeature,
#
#                 style: geo_json_63667abbc54330dad22f6d1f78afb1e0_styler,
#         });
#
#         function geo_json_63667abbc54330dad22f6d1f78afb1e0_add (data) {
#             geo_json_63667abbc543

# %%
import json
geo_path = 'data/hankuk_geo.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))
#print(geo_str)

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
fmap=folium.Choropleth(geo_data = geo_str,
               data = p