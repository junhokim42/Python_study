# %% [markdown]
# # 정적 웹 크롤링과 스크래핑

# %% [markdown]
# ### <span style='color:red'>urllib.request.urlopen()</span> 함수로 웹페이지 소스 크롤링하기

# %%
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print("NAVER 웹페이지의 소스 내용----------------------------------------------------------------")
print(res.read().decode('utf-8'))
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# NAVER 웹페이지의 소스 내용----------------------------------------------------------------
#
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20221110.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function a(){}return a.prototype=n,new a})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,
# useId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"LIVINGHOME_1","unit":"SU10571","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000186","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_2","tb":"LIVINGHOME_1","unit":"SU10572","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]}},
# svt: 20221116133838,
# }; </script> <script> window.nmain.newsstand = {
# rcode: '02310101',
# newsCastSubsInfo: '',
# newsStandSubsInfo: ''
# };
# window.etc = {  };
# window.svr = "<!--cweb12-->"; </script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>   <script src="https://pm.pstatic.net/dist/js/external.2961eaa5.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/preload.5fe99fda.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/polyfill.f3c68d2d.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>  <script src="https://pm.pstatic.net/dist/js/vendors~more~nmain~notice~search~sidebar_notice.40da85e0.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>   <script src="https://pm.pstatic.net/dist/js/search.607b49e4.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>  <script src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notice.7aad5e27.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/nmain.e31af4db.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <style>:root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}</style> </head> <body> <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div> <div id="wrap">         <style>._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;width:18px;height:18px;margin:16px 8px 0 0;background-position:-98px 0}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1syGnXOL._3dsvmZg2:before{background-position:-47px -85px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-position:-21px -89px}._1syGnXOL._2mcQEKCd:before{width:22px;height:22px;margin:14px 7px 0 0;background-position:-47px -63px}._1syGnXOL._36slsKuJ:before{width:21px;height:49px;margin:0 14px 0 0;background-position:0 -63px}._1syGnXOL._3qlJVWzR:before{width:24px;height:49px;margin:0 10px 0 0;background-position:-117px 0}._1syGnXOL._3VkgqBXB:before{width:26px;height:49px;margin:0 10px 0 0;background-position:-116px -54px}._1syGnXOL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{content:none}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{display:inline-block;position:relative;font-size:12px;height:49px;width:78px;text-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-align:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:block;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:before{margin:9px 3px 0 0;width:17px;height:13px;background-position:-89px -63px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;margin-top:14px;float:left;width:98px;height:21px;background-position:0 ...
# <div
# id="NM_TOP_BANNER"
# data-clk-prefix="top"
# class="_1hiMWemA"
# style="background-color: #fff7e1"
# >
# <div class="tY_u8r23">
# <a
# class="_3h-N8T9V"
# href="https://whale.naver.com/banner/details/security/?=main&wpid=RydDy7"
# data-clk="dropbanner1a"
# ></a
# ><span
# class="_1syGnXOL _3VkgqBXB"
# data-clk="dropbanner1a"
# style="padding-right: 20px; font-size: 17px; color: black"
# ><span>매일 쓰는 브라우저 보안이 걱정된다면, </span
# ><strong
# >안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요.</strong
# ></span
# ><a
# href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe"
# class="_2aeXMlrb BMgpjddw"
# id="NM_whale_download_btn"
# data-clk="dropdownload1a"
# ><span style="background-color: #0436c7">다운로드</span></a
# ><button
# type="button"
# data-ui-cookie-exp-days="3"
# data-ui-cookie-key="NM_TOP_PROMOTION"
# data-ui-cookie-value="1"
# data-ui-hide-target="#NM_TOP_BANNER"
# data-clk="dropclose1a"
# class="_20PYt6lT _39oMCV2N"
# >
# 3일 동안 보지 않기
# </button>
# </div>
# </div>
#   <div id="header" role="banner">
#
#
#
#
#
#
#
#
# <div class="special_bg">
# <div class="group_flex">
# <div class="logo_area">
# <h1 class="logo_default">
# <a href="/" class="logo_naver" data-clk="top.logo"
# ><span class="blind">네이버</span></a
# >
# </h1>
# </div>
# <div class="service_area">
# <a id="NM_set_home_btn" href="https://help.naver.com/support/welcomePage/guide.help" class="link_set" data-clk="top.mkhome">네이버를 시작페이지로</a>
# <i class="sa_bar"></i>
# <a href="https://jr.naver.com" class="link_jrnaver" data-clk="top.jrnaver"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>
# <a href="https://happybean.naver.com" class="link_happybin" data-clk="top.happybean"><i class="ico_happybin"></i><span class="blind">해피빈</span></a>
# </div>
#
# <div id="search" class="search_area" data-clk-prefix="sch">
# <form id="sform" name="sform" action="https://search.naver.com/search.naver" method="get" role="search">
# <fieldset>
# <legend class="blind">검색</legend>
# <select id="where" name="where" title="검색 범위 선택" class="blind">
# <option value="nexearch" selected="selected">통합검색</option><option value="post">블로그</option><option value="cafeblog">카페</option><option value="cafe">- 카페명</option><option value="article">- 카페글</option><option value="kin">지식iN</option><option value="news">뉴스</option><option value="web">사이트</option><option value="category">- 카테고리</option><option value="site">- 사이트</option><option value="movie">영화</option><option value="webkr">웹문서</option><option value="dic">사전</option><option value="100">- 백과사전</option><option value="endic">- 영어사전</option><option value="eedic">- 영영사전</option><option value="krdic">- 국어사전</option><option value="jpdic">- 일본어사전</option><option value="hanja">- 한자사전</option><option value="terms">- 용어사전</option><option value="book">책</option><option value="music">음악</option><option value="doc">전문자료</option><option value="shop">쇼핑</option><option value="local">지역</option><option value="video">동영상</option><option value="image">이미지</option><option value="mypc">내PC</option><optgroup label="스마트 파인더"><option value="movie">영화</option><option value="auto">자동차</option><option value="game">게임</option><option value="health">건강</option><option value="people">인물</option></optgroup><optgroup label="네이버 랩"><option>긍정부정검색</option></optgroup>
# </select>
# <input type="hidden" id="sm" name="sm" value="top_hty" />
# <input type="hidden" id="fbm" name="fbm" value="0" />
# <input type="hidden" id="acr" name="acr" value="" disabled="disabled" />
# <input type="hidden" id="acq" name="acq" value="" disabled="disabled" />
# <input type="hidden" id="qdt" name="qdt" value="" disabled="disabled" />
# <input type="hidden" id="ie" name="ie" value="utf8" />
# <input type="hidden" id="acir" name="acir" value="" disabled="disabled" />
# <input type="hidden" id="os" name="os" value="" disabled="disabled" />
# <input type="hidden" id="bid" name="bid" value="" disabled="disabled" />
# <input type="hidden" id="pkid" name="pkid" value="" disabled="disabled" />
# <input type="hidden" id="eid" name="eid" value="" disabled="disabled" />
# <input type="hidden" id="mra" name="mra" value="" disabled="disabled" />
#
#
#
# <div class="green_window" style=''>
# <!-- [AU] data-atcmp-element 에 해당하는 attribute를 추가해주세요. -->
# <input id="query" name="query" type="text" title="검색어 입력" maxlength="255" class="input_text" tabindex="1" accesskey="s" style="ime-mode:active;" autocomplete="off"  placeholder="검색어를 입력해 주세요." onclick="document.getElementById('fbm').value=1;" value="" data-atcmp-element>
# </div>
# <button id="search_btn" type="submit" title="검색" tabindex="3" class="btn_submit" onclick="window.nclick(this,'sch.action','','',event);" style=''>
# <span class="blind">검색</span>
# <span class="ico_search_submit"></span>
# </button>
# </fieldset>
# </form>
# <!-- 한글입력기 -->
# <a href="#" id="ke_kbd_btn" role="button" class="btn_keyboard" onclick="return false;"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>
# <div id="_nx_kbd" style="display:none;"></div>
# <div class="autocomplete">
# <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
# <a href="#" role="button" id="nautocomplete" tabindex="2" class="btn_arw _btn_arw fold" aria-pressed="false" data-atcmp-element><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>
# </div>
# <!-- 자동완성레이어 -->
# <div id="autoFrame" class="reatcmp" style="display: none;">
# <!-- [AU] data-atcmp-element attribute를 추가해주세요. -->
# <div class="ly_atcmp" data-atcmp-element>
# <div class="api_atcmp_wrap">
# <!-- 최근검색어 -->
# <!-- [AU] _recent_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _recent_layer" style="display:none;">
# <!-- [AU] _recent_header 클래스를 추가해주세요. -->
# <div class="atcmp_header _recent_header">
# <strong class="tit">최근검색어</strong>
# <div class="option">
# <!-- [AU] _delAll 클래스를 추가해주세요. -->
# <a role="button" href="#" class="item _delAll" aria-pressed="false">전체삭제</a>
# </div>
# </div>
# <div class="atcmp_container">
# <!-- [AU] _recent 클래스를 추가해주세요. -->
# <ul class="kwd_lst _recent">
# <!-- 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>
# </a>
# <span class="etc">
# <em class="date">@date@.</em>
# <!-- [AU] _del 클래스를 추가해주세요. -->
# <a href="#" role="button" class="bt_item _del" aria-pressed="false"><i class="imsc ico_del">삭제</i></a>
# </span>
# </li>
# </ul>
# <!-- [D] 검색어 저장 꺼진 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _offMsg 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_off _offMsg" style="display: none;">검색어 저장 기능이 꺼져 있습니다.<br><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div>
# <!-- [D] 검색어 내역 없는 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _recentNone 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_none _recentNone" style="display: none;">최근 검색어 내역이 없습니다.<br><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" data-clk="sly.help" target="_blank">도움말</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
# <a href="#" class="close _keywordOnOff">자동저장 끄기</a>
# </span>
# </span>
# </div>
# </div>
# <!-- 자동완성 -->
# <!-- [AU] _atcmp_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _atcmp_layer" style="display:none;">
# <!-- [AU] _words 클래스를 추가해주세요. -->
# <div class="atcmp_container _words">
# <!-- 정답형 템플릿 : 로또당첨번호 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_3" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_lotto _answer" data-template-type="answer_3" data-code="@code@" data-keyword="@1@">
# <a href="#" class="link_item">
# <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
# <div class="dsc_area">
# <span class="tit">@5@회차 당첨번호</span>
# <span class="dsc">
# <span class="item">추첨 @13@.</span><span class="item">지급기한 1년</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc lotto">
# <em class="n@6@">@6@</em><em class="n@7@">@7@</em><em class="n@8@">@8@</em><em class="n@9@">@9@</em><em class="n@10@">@10@</em><em class="n@11@">@11@</em><em class="imsc_bf bonus n@12@">@12@</em>
# </span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 환율 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_9" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_exchange _answer" data-template-type="answer_9" data-code="@code@" data-keyword="@1@">
# <!-- [D] 상승 up, 하락 down 추가 -->
# <a href="#" class="link_item @11@">
# <!-- [D] 국가별 class 가나다순
# ZAR 남아프리카 공화국
# NPR 네팔
# NOK 노르웨이
# NZD 뉴질랜드
# TWD 대만
# DKK 덴마크
# RUB 러시아
# MOP 마카오
# MYR 말레이시아
# MXN 멕시코
# MNT 몽골
# USD 미국
# BHD 바레인
# BDT 방글라데시
# VND 베트남
# BRL 브라질
# SAR 사우디아라비아
# SEK 스웨덴
# CHF 스위스
# SGD 싱가포르
# AED 아랍에미리트
# GBP 영국
# EUR 유럽연합
# ILS 이스라엘
# EGP 이집트
# INR 인도
# IDR 인도네시아
# JPY 일본
# CNY 중국
# CZK 체코
# CLP 칠레
# KZT 카자흐스탄
# QAR 카타르
# CAD 캐나다
# KWD 쿠웨이트
# THB 태국
# TRY 터키
# PKR 파키스탄
# PLN 폴란드
# PHP 필리핀
# HUF 헝가리
# AUD 호주
# HKD 홍콩
# -->
# <span class="common_ico_kwd"><i class="imsc ico @12@">@14@</i></span>
# <div class="dsc_area">
# <span class="tit">@txt@<span class="sub">@currency@</span></span>
# <span class="dsc">
# <span class="item"><i class="imsc ico_arr"></i>@8@(@9@%)</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc"><em class="num">@6@</em>원</span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 날씨(국내11, 해외12) -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_11" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_weather _answer" data-template-type="answer_11" data-code="@code@" data-keyword="@1@">
# <!-- [D] 상승 up, 하락 down 추가 -->
# <a href="#" class="link_item @12@">
# <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
# <div class="dsc_area">
# <span class="tit">@txt@</span>
# <span class="dsc">
# <span class="item">@7@, @message@</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc">
# <!-- [D] 날씨별 class
# ico1 맑음(낮)
# ico2 맑음(밤)
# ico3 구름조금(낮)
# ico4 구름조금(밤)
# ico5 구름많음(낮)
# ico6 구름많음(밤)
# ico7 흐림
# ico8 약한비
# ico9 비
# ico10 강한비
# ico11 약한눈
# ico12 눈
# ico13 강한눈
# ico14 진눈깨비
# ico15 소나기
# ico16 안개
# ico17 소낙눈
# ico18 번개뇌우
# ico19 우박
# ico20 황사
# ico21 비또는눈
# ico22 가끔비
# ico23 가끔눈
# ico24 가끔비또는눈
# ico25 흐린후갬
# ico26 뇌우후갬
# ico27 비후갬
# ico28 눈후갬
# ico29 흐려져비
# ico30 흐려져눈
# -->
# <span class="ico_weather"><i class="imsc ico ico@iconNo@">@7@</i></span>
# <em class="degree">@8@<sup class="celsius">°</sup></em>
# </span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 사이트 바로가기 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_17" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_site _answer" data-template-type="answer_17" data-code="@code@" data-keyword="@1@">
# <a href="@5@" class="link_item" target="_blank">
# <span class="common_ico_kwd"><i class="imsc ico_url"></i></span>
# <div class="dsc_area">
# <span class="tit">@txt@</span>
# <span class="dsc">
# <span class="item">@5@</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc">바로가기</span>
# </span>
# </a>
# </div>
# <!-- [AU] _kwd_list 클래스를 추가해주세요. -->
# <ul class="kwd_lst _kwd_list">
# <!-- [AU] 자동완성 검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
# </a>
# <span class="etc">
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# <!-- [AU] 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item has_correct _item" data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
# </a>
# <span class="etc">
# <!-- 최근검색어 있으면 날짜 표시 -->
# <em class="date">@date@.</em>
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# </ul>
# <!-- [AU] 문맥검색 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="intend" data-keyword="@transQuery@" attribute를 추가해주세요. -->
# <li class="item has_correct _item" data-rank="@rank@" data-intend-rank="@intendRank@" data-template-type="intend" data-keyword="@transQuery@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@intend@</span></span>
# </a>
# <span class="etc">
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# <!-- [D] 선거안내문구 -->
# <!-- [AU] _alert 클래스를 추가해주세요. -->
# <div class="atcmp_alert _alert">
# <div class="dsc_election">
# <p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>
# <span class="dsc_inner">
# <!-- [AU] _alert_passage2 클래스를 추가해주세요. -->
# <span class="_alert_passage2"></span>
# <!-- [AU] _alert_link 클래스를 추가해주세요. -->
# <a href="#" class="link _alert_link" target="_blank">자세히보기</a>
# </span>
# </div>
# </div>
# <!-- [AU] _plus 클래스를 추가해주세요. -->
# <div class="atcmp_plus _plus">
# <div class="dsc_plus">
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="link_dsc" data-clk="sug.cxhelp" target="_blank">관심사를 반영한 컨텍스트 자동완성<i class="imsc ico_help">도움말</i></a>
# </div>
# <div class="switch">
# <!-- [D] 선택시 aria-pressed="ture/false" -->
# <!-- [AU] _plus_btn 클래스를 추가해주세요. -->
# <a role="button" href="#" class="bt_switch active _plus_btn" aria-pressed="false"><i class="imsc ico_option">컨텍스트 자동완성</i></a>
# </div>
# <!-- [AU] _plus_layer 클래스를 추가해주세요. -->
# <div class="layer_plus _plus_layer">
# <strong class="tit">컨텍스트 자동완성</strong>
# <!-- [AU] _plus_layer_isloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isloggedin" style="display:none">
# <p class="dsc">ON/OFF 설정은<br>해당기기(브라우저)에 저장됩니다.</p>
# <div class="btn_area">
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="btn btn_view" data-clk="sug.cxlink" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_isnotloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isnotloggedin" style="display:none">
# <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br>관심사에 맞춰 자동완성을 제공합니다.</p>
# <div class="btn_area">
# <a href="https://nid.naver.com/nidlogin.login" class="btn btn_login" data-clk="sug.cxlogin">로그인</a>
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="btn btn_view" data-clk="sug.cxlink" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_close 클래스를 추가해주세요. -->
# <a href="#" role="button" class="btn_close _plus_layer_close"><i class="imsc ico_close">컨텍스트 자동완성 레이어 닫기</i></a>
# </div>
# </div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a href="https://help.naver.com/alias/search/word/word_17.naver" data-clk="sug.help" target="_blank">도움말</a></span>
# <span class="opt_item"><a href="https://help.naver.com/support/contents/contents.help?serviceNo=605&categoryNo=18215" class="report" data-clk="sug.report" target="_blank">신고</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
# <a href="#" class="close _suggestOnOff">자동완성 끄기</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
# </div>
# </div>
#
# <!--EMPTY-->
# <div id="gnb" role="navigation">
# <div id="NM_FAVORITE" class="gnb_inner">
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a href="https://mail.naver.com/" class="nav" data-clk="svc.mail"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a href="https://section.cafe.naver.com/" class="nav" data-clk="svc.cafe">카페</a></li>
# <li class="nav_item"><a href="https://section.blog.naver.com/" class="nav" data-clk="svc.blog">블로그</a></li>
# <li class="nav_item"><a href="https://kin.naver.com/" class="nav" data-clk="svc.kin">지식iN</a></li>
# <li class="nav_item"><a href="https://shopping.naver.com/" class="nav shop" data-clk="svc.shopping"><span class="blind">쇼핑</span></a></li>
# <li class="nav_item"><a href="https://shoppinglive.naver.com/home" class="nav shoplive"
# data-clk="svc.shoppinglive"><span class="blind">쇼핑LIVE</span></a></li>
# <li class="nav_item"><a href="https://order.pay.naver.com/home" class="nav" data-clk="svc.pay">Pay</a></li>
# <li class="nav_item">
# <a href="https://tv.naver.com/" class="nav" data-clk="svc.tvcast"><i class="ico_tv"></i>TV</a>
# </li>
# </ul>
# <ul
# class="list_nav NM_FAVORITE_LIST"
# >
# <li class="nav_item"><a href="https://dict.naver.com/" class="nav" data-clk="svc.dic">사전</a></li>
# <li class="nav_item"><a href="https://news.naver.com/" class="nav" data-clk="svc.news">뉴스</a></li>
# <li class="nav_item"><a href="https://finance.naver.com/" class="nav" data-clk="svc.stock">증권</a></li>
# <li class="nav_item"><a href="https://land.naver.com/" class="nav" data-clk="svc.land">부동산</a></li>
# <li class="nav_item"><a href="https://map.naver.com/" class="nav" data-clk="svc.map">지도</a></li>
# <li class="nav_item"><a href="https://vibe.naver.com/" class="nav" data-clk="svc.vibe">VIBE</a></li>
# <li class="nav_item"><a href="https://search.shopping.naver.com/book/home" class="nav" data-clk="svc.book">도서</a></li>
# <li class="nav_item"><a href="https://comic.naver.com/" class="nav" data-clk="svc.webtoon">웹툰</a></li>
#
# </ul>
# <ul class="list_nav type_empty" style="display: none;"></ul>
# <a href="#" role="button" class="btn_more" data-clk="svc.more">더보기</a>
# <div class="ly_btn_area">
# <a href="more.html" class="btn NM_FAVORITE_ALL" data-clk="map.svcmore">서비스 전체보기</a>
# <a href="#" role="button" class="btn btn_set" data-clk="map.edit">메뉴설정</a>
# <a href="#" role="button" class="btn btn_reset" data-clk="edt.reset">초기화</a>
# <a href="#" role="button" class="btn btn_save" data-clk="edt.save">저장</a>
# </div>
# </div>
# <div id="NM_WEATHER" class="group_weather">
# <div>
# <a data-clk="squ.weat" href="https://weather.naver.com/today/02310101?cpName=KMA" class="weather_area ico_w07">
# <div class="current_box">
# <strong class="current" aria-label="현재기온">11.9°</strong><strong class="state">흐림</strong>
# </div>
# <div class="degree_box">
# <span class="min" aria-label="최저기온">5.0°</span><span class="max" aria-label="최고기온">13.0°</span>
# </div>
# <span class="location">갈매동</span>
# </a>
# </div>
# <div>
# <a data-clk="squ.dust" href="https://weather.naver.com/today/02310101?cpName=KMA" class="air_area">
# <ul class="list_air">
# <li class="air_item">미세<strong class="state state_normal">보통</strong></li>
# <li class="air_item">초미세<strong class="state state_bad">나쁨</strong></li>
# </ul>
# <span class="location">갈매동</span>
# </a>
# </div>
#
# </div>
# </div>
# <div class="ly_service">
# <div class="group_service NM_FAVORITE_ALL_LY"></div>
# <div class="group_service NM_FAVORITE_EDIT_LY" style="display: none;"></div>
# </div>
# </div>
# </div>
#  <div id="container" role="main"> <div style="position:relative;width:1130px;margin:0 auto;z-index:11"> <div id="da_top"></div> <div id="da_expwide"></div> </div> <div id="NM_INT_LEFT" class="column_left"> <div id="veta_top"> <div id="veta_top_inner" style="height:135px"> </div> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div> <div id="newsstand" class="sc_newscast"> <h2 class="blind">뉴스스탠드</h2> <div id="NM_NEWSSTAND_HEADER" class="group_issue" data-clk-prefix="ncy"> <div class="issue_area"> <a class="link_media" href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y" data-clk="newsflash">연합뉴스</a> <div id="NM_ONELINE_ROLLING" class="list_issue" data-nm-ui="rolling"> <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013579157" class="issue" data-clk="quickarticle">검찰, '이재명 최측근' 정진상 구속영장</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013579156" class="issue" data-clk="quickarticle">폴란드에 떨어진 미사일은 누가 쐈나…추측 '분분'</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013579076" class="issue" data-clk="quickarticle">트럼프, 2024년 대선출마 공식선언…"바이든 4년 더 안 돼"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013579086" class="issue" data-clk="quickarticle">특수본, 이상민 행안장관 본격 수사 검토…"지휘의무 확인중"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013579176" class="issue" data-clk="quickarticle">오세훈 "이태원 참사 원인은 시·행안부·경찰의 예측 실패"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013579121" class="issue" data-clk="quickarticle">경찰, '이태원 희생자 명단공개' 고발사건 수사 개시</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013579074" class="issue" data-clk="quickarticle">[이태원 참사] 정부 "과거엔 신원확인 오래 걸려 실종자 명단 공개"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013579149" class="issue" data-clk="quickarticle">"접종해도 걸리는데" "부작용 걱정에"…추가 접종률 4.8% 그쳐</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013579181" class="issue" data-clk="quickarticle">연준 보고서 "주담대 금리 부담에 미국 집값 20% 하락 가능성"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013579093" class="issue" data-clk="quickarticle">국민 절반은 '결혼 안해도 된다'…안하는 이유 1위 '돈 없어서'</a></div> </div> </div> <div class="direct_area"> <a href="https://m.sports.naver.com/qatar2022/index" class="link_worldcup" data-clk="qatar2022"><span class="blind">QATAR 2022</span></a> <a href="http://news.naver.com/" class="link_news" data-clk="newshome">뉴스홈</a>
# <a href="http://entertain.naver.com/home" class="link_direct" data-clk="entertainment">연예</a>
# <a href="http://sports.news.naver.com/" class="link_direct" data-clk="sports">스포츠</a>
# <a href="http://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101" class="link_direct" data-clk="economy">경제</a> </div> </div>        <div id="NM_NEWSSTAND_TITLE" class="group_title" data-clk-prefix="nsd"> <a href="http://newsstand.naver.com/" class="link_newsstand" data-clk="title" target="_blank">뉴스스탠드</a> <div id="NM_NEWSSTAND_data_buttons" class="sort_area" role="tablist">  <a href="#" role="tab" data-type="my" data-clk="my" class="btn_sort" aria-controls="NM_NEWSSTAND_MY_LIST" aria-selected="false">구독한 언론사</a> <a href="#" role="tab" data-type="all" data-clk="all" class="btn_sort" aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true">전체언론사</a>  </div> <div id="NM_NEWSSTAND_view_buttons" class="set_area" role="tablist">  <a href="#" role="tab" data-type="list" data-clk="articleview" class="btn_set" aria-controls="NM_NEWSSTAND_DEFAULT_LIST" aria-selected="false"> <i class="ico_list"><span class="blind">리스트형</span></i></a> <a href="#" role="tab" data-type="thumb" data-clk="pressview" class="btn_set" aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true"> <i class="ico_tile"><span class="blind">썸네일형</span></i></a>  <a href="http://newsstand.naver.com/config.html" class="btn_set" data-clk="set" target="_blank"> <i class="ico_set"><span class="blind">설정</span></i></a> </div> </div> <div id="NM_NEWSSTAND_VIEW_CONTAINER" style="position:relative"> <div id="NM_NEWSSTAND_DEFAULT_LIST" class="group_news" role="tabpanel" style="display:none" data-clk-prefix="nsd_all"> <a href="#" role="button" class="pm_btn_prev_l _NM_NEWSSTAND_LIST_prev_btn" data-clk-custom="prev"><i class="ico_btn"><span class="blind">이전</span></i></a> <a href="#" role="button" class="pm_btn_next_l _NM_NEWSSTAND_LIST_next_btn" data-clk-custom="next"><i class="ico_btn"><span class="blind">다음</span></i></a> <div class="list_view"> <div class="option_area"> <div class="list_option_wrap"> <ul class="list_option"> <li class="option_item" data-cateid="ct2"><a href="#" class="option" data-clk="daei">종합/경제</a></li> <li class="option_item" data-cateid="ct3"><a href="#" class="option" data-clk="dtvcom">방송/통신</a></li> <li class="option_item" data-cateid="ct4"><a href="#" class="option" data-clk="dit">IT</a></li> <li class="option_item" data-cateid="ct5"><a href="#" class="option" data-clk="deng">영자지</a></li> <li class="option_item" data-cateid="ct6"><a href="#" class="option" data-clk="dsporent">스포츠/연예</a></li> <li class="option_item" data-cateid="ct7"><a href="#" class="option" data-clk="dmagtec">매거진/전문지</a></li> <li class="option_item" data-cateid="ct8"><a href="#" class="option" data-clk="dloc">지역</a></li> </ul> </div> </div> <div class="_NM_NEWSSTAND_ARTICLE_CONTAINER" data-clk-sub="*a"></div> </div> <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_invalid" style="display:none" data-clk-sub="*a"> <a href="#" role="button" class="btn_close NM_NEWSSTAND_POPUP_CLOSE"><i class="ico_close"></i><span class="blind">닫기</span></a> <p class="popup_msg">해당 언론사 사정으로 접근이 제한됩니다.</p> <div class="popup_btn"> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE">확인</a> </div> </div> <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_undescribe_confirm" style="display:none" data-clk-sub="*a"> <a href="#" role="button" class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose"><i class="ico_close"></i><span class="blind">닫기</span></a> <p class="popup_msg"><strong class="NM_NEWSSTAND_POPUP_PNAME"></strong>을(를)<br>구독해지 하시겠습니까?</p> <div class="popup_btn"> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone">확인</a> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel">취소</a> </div> </div> <div class="ly_toast NM_NEWSSTAND_TOAST" style="display:none"> <p class="toast_msg">구독한 언론사에 추가되었습니다.</p> </div> </div>   <div id="NM_NEWSSTAND_DEFAULT_THUMB" class="group_news" role="tabpanel" style="display:block" data-clk-prefix="nsd_all"> <a href="#" role="button" class="pm_btn_prev ...
# <div class="tile_view">
# <div class="frame_area">
# <i class="line to_right1"></i>
# <i class="line to_right2"></i>
# <i class="line to_right3"></i>
# <i class="line to_bottom1"></i>
# <i class="line to_bottom2"></i>
# <i class="line to_bottom3"></i>
# <i class="line to_bottom4"></i>
# <i class="line to_bottom5"></i>
# </div>
# <div class="thumb_area">
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="002"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/002.png"
# height="20"
# alt="프레시안"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="002"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="002"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=002"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="002"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="008"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/008.png"
# height="20"
# alt="머니투데이"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="008"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="008"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=008"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="008"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="023"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/up/2020/0903/nsd185255316.png"
# height="20"
# alt="조선일보"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="023"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="023"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=023"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="023"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="109"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/up/2020/0610/nsd151458769.png"
# height="20"
# alt="OSEN"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="109"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="109"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=109"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="109"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="073"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/up/2020/0708/nsd94830278.png"
# height="20"
# alt="스포츠서울"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="073"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="073"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=073"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="073"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="011"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2019/logo/011.png"
# height="20"
# alt="서울경제"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="011"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="011"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=011"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="011"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="055"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/055.png"
# height="20"
# alt="SBS"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="055"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="055"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=055"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="055"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="022"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/022.png"
# height="20"
# alt="세계일보"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="022"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="022"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=022"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="022"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="025"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/up/2021/0824/nsd115034872.png"
# height="20"
# alt="중앙일보"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="025"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="025"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=025"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="025"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="029"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/029.png"
# height="20"
# alt="디지털타임스"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="029"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="029"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=029"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="029"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="366"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/366.png"
# height="20"
# alt="조선비즈"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="366"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="366"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=366"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="366"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="308"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/308.png"
# height="20"
# alt="시사인"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="308"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="308"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=308"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="308"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="016"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/016.png"
# height="20"
# alt="헤럴드경제"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="016"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="016"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=016"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="016"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="904"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/904.png"
# height="20"
# alt="JTBC"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="904"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="904"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=904"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="904"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="277"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/277.png"
# height="20"
# alt="아시아경제"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="277"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="277"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=277"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="277"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="688"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/up/2022/1017/nsd202616515.png"
# height="20"
# alt="경기신문"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="688"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="688"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=688"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="688"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="339"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/339.png"
# height="20"
# alt="경기일보"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="339"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="339"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=339"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="339"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="909"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"
# height="20"
# alt="기호일보"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="909"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="909"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=909"
# target="_blank"
# ...
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34760636&amp;memberNo&#x3D;783179" class="theme_info" data-clk="tcc_aut.list11cont5" target="_blank">
# 						<em class="theme_category"> 자동차</em>
# 						<strong class="title elss">포르쉐 타이칸, 3년 만에 누적 생산량 10만대 돌파…국내서만 2378대 판매</strong>
#                         <p class="desc">포르쉐가 지난 7일 자사 최초의 순수 전기 스포츠카 &#x27;타이칸&#x27;의 10만 번째 차량을 생산했다고 밝혔습니다. 포르쉐 타이칸은 지난 2019년 9월 주펜하우젠 공장에서 처음 생산을 시작한 이후 약 3년 만에 10만대 누적 생산의 역사적인 이정표를 세웠습니다. 타이칸 제품 라인 부사장 케빈 기에크는 “최근 반도체 부족, 코로나 확산의 어려움 속에서도 </p>
# 						<div class="source_box">
# 							<span class="date">1주일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">오토이슈</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 		</ul>
# 	</div>
# </div>
# <div class="group_theme" data-block-id="" data-block-code="PC-THEME-CARGAME-MOBILE-RANKING-DEFAULT-11" data-block-type="MATERIALS" data-template-code="MOBILE-RANKING-LIST"
#
# 	 data-da="container"
# 	 data-index=""
#      data-page="6"
# 	 style="display:none">
#
# 	<div class="list_theme_wrap">
# 		<ul class="list_theme">
#
# 				<li class="theme_item" data-gdid="CAS_247760ef-614e-11ed-b4ea-87a358b48f4c" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34769443&amp;memberNo&#x3D;23315462" class="theme_thumb" data-clk="tcc_aut.list12cont1" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20221111_1095%2Fupload_1668122403780xuPNW.jpg%22&amp;type&#x3D;nf340_228" alt="&quot;제대로 붙어보자&quot; 볼보, 드디어 베일을 벗은 EX9" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34769443&amp;memberNo&#x3D;23315462" class="theme_info" data-clk="tcc_aut.list12cont1" target="_blank">
# 						<em class="theme_category"> 자동차</em>
# 						<strong class="title elss">"제대로 붙어보자" 볼보, 드디어 베일을 벗은 EX9</strong>
#                         <p class="desc">지난 9일(현지시간), 볼보가 순수 전기 SUV EX90을 공개했다. 오프라인으로 스웨덴 스톡홀름에서 진행된 이날 행사는 온라인에서도 동시에 중계되었다. 과연 EX90은 어떤 특징을 가지고 있을까? 지금부터 함께 알아보자. EX90은 어떤차? EX90는 볼보의 전기차 전용 플랫폼 SPA2를 기반으로 한 첫 전용 전기차다. 전반적인 디자인은 지난해 공개한 ‘</p>
# 						<div class="source_box">
# 							<span class="date">5일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">다키포스트</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_247760f0-614e-11ed-b4ea-e3f438266520" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34770794&amp;memberNo&#x3D;31381824" class="theme_thumb" data-clk="tcc_aut.list12cont2" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20221111_1095%2Fupload_16681224098090MRCZ.jpg%22&amp;type&#x3D;nf340_228" alt="벤틀리 벤테이가 오디시안 에디션 공개!! 전세계 70대 한정판" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34770794&amp;memberNo&#x3D;31381824" class="theme_info" data-clk="tcc_aut.list12cont2" target="_blank">
# 						<em class="theme_category"> 자동차</em>
# 						<strong class="title elss">벤틀리 벤테이가 오디시안 에디션 공개!! 전세계 70대 한정판</strong>
#                         <p class="desc">벤틀리 벤테이가 오디시안 에디션 공개!! 전세계 70대 한정판안녕하세요 신차연구소 카랩입니다. 지난1일 벤틀리에서 벤테이가 오디시안 에디션을 공개했습니다. 벤테이가 오디시안 에디션은 전세계 70대 한정 판매 된다고 합니다. 벤테이가 오디시안 에디션의 파워트레인은 3.0리터 V6 가솔린 엔진과 전기모터, 18kWh 용량의 배터리가 탑재되어, 최대출력 462마</p>
# 						<div class="source_box">
# 							<span class="date">5일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">신차연구소 카랩</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_247760ed-614e-11ed-b4ea-0fc2ce2b5bdc" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34770007&amp;memberNo&#x3D;32157774" class="theme_thumb" data-clk="tcc_aut.list12cont3" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20221111_1095%2Fupload_166812240702276Gay.jpg%22&amp;type&#x3D;nf340_228" alt="외모부터 이름까지 변경... 아우디 Q8 e-트론 &amp; SQ8 e-트론 공개" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34770007&amp;memberNo&#x3D;32157774" class="theme_info" data-clk="tcc_aut.list12cont3" target="_blank">
# 						<em class="theme_category"> 자동차</em>
# 						<strong class="title elss">외모부터 이름까지 변경... 아우디 Q8 e-트론 & SQ8 e-트론 공개</strong>
#                         <p class="desc">아우디는 전기차 모델에 ‘e-트론(e-tron)’이라는 이름을 붙인다. 기본 e-트론 모델은 SUV이며 쿠페형 SUV는 e-트론 스포트백, 4도어 쿠페 모델은 e-트론 GT라는 이름으로 불렸다. 그런데 갑자기 Q4 e-트론, Q6 e-트론 등 모델이 추가되면서 아우디 작명법에 혼란이 가중됐다. 그런 아우디가 Q8 e-트론</p>
# 						<div class="source_box">
# 							<span class="date">5일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">오토뷰</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_a05ae0a4-6000-11ed-9e2e-ef827c835c84" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34756857&amp;memberNo&#x3D;23315462" class="theme_thumb" data-clk="tcc_aut.list12cont4" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20221109_1095%2Fupload_1667979174730XLTxH.jpg%22&amp;type&#x3D;nf340_228" alt="&quot;11,000km 주행가능&quot; 현대차 10배인 &#x27;이 차&#x27; 앞으로 대세가 될 까?" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34756857&amp;memberNo&#x3D;23315462" class="theme_info" data-clk="tcc_aut.list12cont4" target="_blank">
# 						<em class="theme_category"> 자동차</em>
# 						<strong class="title elss">"11,000km 주행가능" 현대차 10배인 '이 차' 앞으로 대세가 될 까?</strong>
#                         <p class="desc">태양으로부터 얻는 에너지는 무한하다. 사람들은 태양광 발전 등을 통한 친환경 에너지를 적극적으로 추진하고 있다. 화석연료나 원자력을 이용하지 않아도 되는 만큼 환경에 도움이 되기 때문이다. 한편 자동차에도 태양광 발전 시스템이 들어간 차들이 계속해서 등장하고 있다. 달리면서 충전을 한다는 개념 자체는 제조사나 소비자 입장에서 매력적인 모습이기 때문이다.이런</p>
# 						<div class="source_box">
# 							<span class="date">1주일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">다키포스트</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_06bfbdfd-5f38-11ed-b6d9-d32fefcf47a8" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34755797&amp;memberNo&#x3D;40524516" class="theme_thumb" data-clk="tcc_aut.list12cont5" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20221108_1095%2Fupload_1667892997913v9QvJ.jpg%22&amp;type&#x3D;nf340_228" alt="[시승기] “이 차가 왜 놀라운지 하나씩 알려드립니다” EV6 GT" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;34755797&amp;memberNo&#x3D;40524516" class="theme_info" data-clk="tcc_aut.list12cont5" target="_blank">
# 						<em class="theme_category"> 자동차</em>
# 						<strong class="title elss">[시승기] “이 차가 왜 놀라운지 하나씩 알려드립니다” EV6 GT</strong>
#                         <p class="desc">학교 운동장에서 100미터 달리기를 몇 초에 뛰었는지 기억하는가? 나 역시 정확히 기억은 나지 않지만 전력 질주할 때 얼굴을 스치는 바람의 느낌은 또렷하다. 아마도 15초를 넘겼겠지? 단거리 달리기에는 그다지 소질이 없었다. 그랬던 내가 이제 같은 100미터를 1.3초대에 통과한다. 바람마저 갈라버릴 가공할 스피드. 260km/h 이상에서도 굳건한 안정감을</p>
# 						<div class="source_box">
# 							<span class="date">1주일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">카피엔스</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 		</ul>
# 	</div>
# </div>
#
#
#
#
# 	<div class="btn_more_wrap">
# 		<button type="button" class="btn_more" data-clk-custom="tcc_aut.more" data-next-page="2"><i class="ico_more"></i>새로운 글 더보기</button>
# 	</div>
#
#
# <div class="NM_THEME_META" style="display: none" data-panel-code="CARGAME" data-parent-code=""></div>
#
# 	</div>
# </div>
#  </div> </div> <div id="NM_INT_RIGHT" class="column_right"> <div class="column_fix_wrap"> <div id="da_brand"></div>
#
#
#
#
#
# <div id="account" class="sc_login">
# <h2 class="blind">Sign in</h2>
# <p class="login_msg">Connect with people</p>
# <a href="https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com" class="link_login" data-clk="log_off.login"><i class="ico_naver"><span class="blind">NAVER</span></i>Sign in</a>
# <div class="sub_area">
# <div class="look_box">
# <a href="https://nid.naver.com/user/help.nhn?todo=idinquiry" class="link_look" data-clk="log_off.searchid">Forgot Username</a>
# <a href="https://nid.naver.com/nidreminder.form" class="link_look" data-clk="log_off.searchpass">Password</a>
# </div>
# <a href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com" class="link_join" data-clk="log_off.registration">Sign up</a>
# </div>
# </div>
#
#
#
#  <div id="timesquare" class="sc_timesquare"> <h2 class="blind">타임스퀘어</h2> <div class="card_wrap">
# <div class="card_nav">
# <a href="#" role="button" class="btn_nav btn_prev" data-clk="squ.pre"><span class="blind">이전</span></a>
# <a href="#" role="button" class="btn_nav btn_next" data-clk="squ.next"><span class="blind">다음</span></a>
# </div>
# <div id="NM_TS_ROLLING_WRAP" style="height: 100%;">
# <div>
# <a href="https://search.naver.com/search.naver?sm=top_hty&amp;fbm=0&amp;ie=utf8&amp;query=%EC%BD%94%EB%A1%9C%EB%82%9819" class="card_news" data-clk="squ.line3"><i class="news_badge">이슈</i><span class="news">코로나바이러스감염증-19 현황</span></a>
# </div>
# <div>
# <a href="https://finance.naver.com/sise/sise_index.nhn?code=KOSPI" class="card_stock " data-clk="squ.kospi">
# <strong class="stock_title">증시</strong>
# <div class="stock_box">
# <em class="name">코스피</em>
# <strong class="current">2,469.38</strong>
# <span class="rate rate_down"><span class="blind">하락</span>10.95 -0.44%</span>
# </div>
# </a>
# </div>
# <div>
# <a href="https://finance.naver.com/sise/sise_index.nhn?code=KOSDAQ" class="card_stock " data-clk="squ.kosdaq">
# <strong class="stock_title">증시</strong>
# <div class="stock_box">
# <em class="name">코스닥</em>
# <strong class="current">741.98</strong>
# <span class="rate rate_down"><span class="blind">하락</span>2.98 -0.40%</span>
# </div>
# </a>
# </div>
# <div>
# <a href="https://finance.naver.com/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" class="card_stock type_exchange" data-clk="squ.usd">
# <strong class="stock_title">환율</strong>
# <div class="stock_box">
# <em class="name">USD</em>
# <strong class="current">1,330.30</strong>
# <span class="rate rate_up"><span class="blind">상승</span>14.30 +1.09%</span>
# </div>
# </a>
# </div>
# </div>
# </div> <!-- EMPTY --> </div> <div id="veta_branding"> <span class="blind"> <script id="veta_service_check"></script> </span> <div id="veta_branding_inner" style="width:350px;height:200px"> </div> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div> <div id="shopcast" class="sc_shopcast"> <iframe id="shopcast_iframe" data-iframe-src="/shoppingbox/shoppingboxnew/main.nhn?mode=plusdeal&domain=N" title="쇼핑캐스트" width="350" height="1809" marginheight="0" marginwidth="0" scrolling="no" frameborder="0"></iframe> </div> </div> </div> <a id="NM_scroll_top_btn" href="#wrap" class="content_top"><span class="blind">TOP</span></a> <button id="NM_darkmode_btn" type="button" role="button" class="btn_theme" aria-pressed="false"  > <span class="blind">라이트 모드로 보기</span> </button> </div> <div id="footer" role="contentinfo"> <div class="footer_inner"> <div id="NM-FOOTER-AD" class="banner_area"> <div class="da_box_wrap"> <div id="da_public_left"> </div> <div id="da_public_right"> </div> <div id="veta_time2"> </div> </div> </div> <div class="notice_area" data-clk-prefix="ntc"> <div class="notice_box"> <h3 class="title"><a href="https://www.naver.com/NOTICE">공지사항</a> </h3> <!-- EMPTY --> </div> <a href="more.html" class="link_all" data-clk="svcmap">서비스 전체보기</a> </div> <div class="aside_area"> <div class="partner_box_wrap"> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Creators</h3> <a href="https://www.navercorp.com/service/creators" class="link_partner" data-clk="creator">크리에이터</a> <a href="https://www.navercorp.com/service/business" class="link_partner" data-clk="smbusiness">스몰비즈니스</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Partners</h3> <a href="https://campaign.naver.com/smefullcare/online/" class="link_partner" data-clk="sme">SME 풀케어 시스템</a> <a href="https://business.naver.com/service.html" class="link_partner" data-clk="service">비즈니스 · 광고</a> <a href="https://sell.storefarm.naver.com/#/home/about" class="link_partner" data-clk="store">스토어 개설</a> <a href="https://smartplace.naver.com" class="link_partner" data-clk="place">지역업체 등록</a> <a href="https://expert.naver.com/expert/introduction?tab=guide#join" class="link_partner" data-clk="expert">엑스퍼트 등록</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Developers</h3> <a href="https://developers.naver.com" class="link_partner" data-clk="center">네이버 개발자 센터</a> <a href="https://developers.naver.com/docs/common/openapiguide/#/apilist.md" class="link_partner" data-clk="openapi">오픈 API</a> <a href="https://naver.github.io" class="link_partner" data-clk="opensource">오픈소스</a> <a href="https://d2.naver.com" class="link_partner" data-clk="d2">네이버 D2</a> <a href="http://d2startup.com" class="link_partner" data-clk="naverD2SF">네이버 D2SF</a> <a href="https://www.naverlabs.com" class="link_partner" data-clk="labs">네이버 랩스</a> </div> </div> <div class="service_box_wrap"> <div class="service_box" data-clk-prefix="wbd"> <a href="http://whale.naver.com/" class="service_logo" data-clk="bt"> <img src="data:image/png;base64,..." alt="웨일" width="48" height="48"> </a> <div class="service_info"> <strong class="title">웨일 브라우저</strong> <a href="http://whale.naver.com/" class="dsc" data-clk="bt">다운받기</a> </div> </div> <div class="service_box" data-clk-prefix="prj"> <a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83" class="service_logo" data-clk="link"> <img src="data:image/png;base64,..." alt="꽃" width="47" height="50"> </a> <div class="service_info"> <strong class="title">프로젝트 꽃</strong> <a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83" class="dsc" data-clk="link">바로가기</a> </div> </div> </div> </div> <div class="corp_area" data-clk-prefix="plc"> <h3 class="blind">네이버 정책 및 약관</h3> <ul class=" ...

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/tagstyle.html")
print(res)
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
print(res.read()) # 바이트 문자열, 바이트열 - b'..............'
#print(res.read().decode('utf-8'))
# Out:
# <http.client.HTTPResponse object at 0x000002223865A920>
# [ header 정보 ]----------
# ('Date', 'Wed, 16 Nov 2022 05:05:58 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '461')
# ('Connection', 'close')
# ('Content-Type', 'text/html')
# [ body 내용 ]-----------
# b'<!DOCTYPE html>\r\n<html>\r\n<head>\r\n<meta charset="UTF-8">\r\n<title>Insert title here</title>\r\n</head>\r\n<body>\r\n<h1>\xeb\xb8\x94\xeb\x9f\xad\xec\x8a\xa4\xed\x83\x80\xec\x9d\xbc \xed\x83\x9c\xea\xb7\xb8</h1>\r\n<div style="background-color:yellow">\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa41</div>\r\n<div>\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa42</div>\r\n<div>\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa43</div>\r\n<hr>\r\n<h1>\xec\x9d\xb8\xeb\x9d\xbc\xec\x9d\xb8\xec\x8a\xa4\xed\x83\x80\xec\x9d\xbc \xed\x83\x9c\xea\xb7\xb8</h1>\r\n<span style="background-color:yellow">\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa41</span>\r\n<span>\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa42</span>\r\n<span>\xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa43</span>\r\n</body>\r\n</html>'

# %%
import urllib.request
print("===========================================================")
url = 'https://www.python.org/'
f = urllib.request.urlopen(url)
print(type(f))
print(type(f.info()))
encoding = f.info().get_content_charset()
encoding = 'utf-8' if encoding == None else encoding
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'https://www.daum.net/'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset() 
encoding = 'utf-8' if encoding == None else encoding
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'http://www.yes24.com/Main/default.aspx'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
encoding = 'utf-8' if encoding == None else encoding
print(url, ' 페이지의 인코딩 정보 :', encoding)

text = f.read(500).decode(encoding)
print(text)
print("===========================================================")
# Out:
# ===========================================================
# <class 'http.client.HTTPResponse'>
# <class 'http.client.HTTPMessage'>
# https://www.python.org/  페이지의 인코딩 정보 : utf-8
# <!doctype html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jqu
# ===========================================================
# https://www.daum.net/  페이지의 인코딩 정보 : utf-8
# <!DOCTYPE html><html lang="ko"> <head> <meta charset="utf-8" /> <title>Daum</title> <meta http-equiv="x-ua-compatible" content="IE=edge" /> <meta property="og:url" content="//www.daum.net/" /> <meta property="og:type" content="website" /> <meta property="og:title" content="Daum" /> <meta http-equiv="Pragma" content="no-cache" /> <meta http-equiv="Expires" content="-1" /> <meta name="referrer" content="origin" /> <meta property="og:image" content="https://i1.daumcdn.net/svc/image/U03/common_icon/
# ===========================================================
# http://www.yes24.com/Main/default.aspx  페이지의 인코딩 정보 : ks_c_5601-1987
#
# 	<!DOCTYPE html>
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=euc-kr" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title>Y
# ===========================================================

# %% [markdown]
# ### urllib.parse.urlencode() 함수로 Query 문자열(요청 파라미터) 인코딩하기

# %%
import urllib
print("[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urllib.parse.urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
params2 = urllib.parse.urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)
# Out:
# [ Query문자열 또는 요청 파라미터 인코딩 ]
# number=12524&type=issue&action=show
# addr=%EC%84%9C%EC%9A%B8%EC%8B%9C+%EA%B0%95%EB%82%A8%EA%B5%AC+%EC%97%AD%EC%82%BC%EB%8F%99

# %%
import urllib
print(urllib.parse.quote_plus('가나다 ABC123'))
query_str1 = "q="+urllib.parse.quote_plus('가나 다')
query_str2 = urllib.parse.urlencode({"q" : "가나 다"})
print("-------------------------------------------")
print(query_str1)
print(query_str2)
# Out:
# %EA%B0%80%EB%82%98%EB%8B%A4+ABC123
# -------------------------------------------
# q=%EA%B0%80%EB%82%98+%EB%8B%A4
# q=%EA%B0%80%EB%82%98+%EB%8B%A4

# %% [markdown]
# ### Query 문자열 전달하면서 GET 방식으로 요청하기

# %%
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % params)
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % params
print("URL 문자열 : %s" % url)
with urllib.request.urlopen(url) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# URL 문자열 : http://unico2013.dothome.co.kr/crawling/get.php?name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %% [markdown]
# ### 요청 파라미터 전달하면서 POST 방식으로 요청하기(1)

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % data)
postdata = data.encode('ascii')
print("변환된 바이트 문자열 : %s" % postdata)
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, postdata) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# 변환된 바이트 문자열 : b'name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10'
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %% [markdown]
# ### 요청 파라미터 전달하면서 POST 방식으로 요청하기(2)

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))
# Out:
# <urllib.request.Request object at 0x000002223880AF50>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %% [markdown]
# ### <span style='color:red'>requests.request()</span> 함수로 웹페이지 소스 크롤링하기

# %%
import requests

r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# 응답된 콘텐츠가 없어요
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 백도이고 나이는 12이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# {'Date': 'Wed, 16 Nov 2022 06:08:49 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'Content-Length': '164', 'Connection': 'close', 'Content-Type': 'text/html'}
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>

# %%
import requests

dicdata = {'key1': 'value1', 'key2': 'value2'}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')]
r = requests.get(urlstr, params=tupledata)
print(r.url)
# Out:
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2&key2=value3
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key1=value2

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)
print('------------------------------------')
r.encoding = 'utf-8'
print(r.text)
print('------------------------------------')
print(r.content)
print('------------------------------------')
print(r.content.decode('utf-8'))
# Out:
# ï»¿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : ì´ë¦ê³¼ ëì´ë¥¼ ì ë¬í´ ì£¼ì¸ì!!</h1>   </body>
# </html>
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ------------------------------------
# b'\xef\xbb\xbf<!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <title>POST TEST</title>\r\n  </head>\r\n  <body>\r\n   <h1>GET : \xec\x9d\xb4\xeb\xa6\x84\xea\xb3\xbc \xeb\x82\x98\xec\x9d\xb4\xeb\xa5\xbc \xec\xa0\x84\xeb\x8b\xac\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94!!</h1>   </body>\r\n</html>'
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %% [markdown]
# ### 이미지 크롤링하여 파일로 저장하기

# %%
import requests
from PIL import Image
from io import BytesIO

r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
i = Image.open(BytesIO(r.content))
print(type(i))
i.save("c:/Temp/test.jpg")
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %% [markdown]
# ### 크롤링한 웹페이지 내용을 BeautifulSoup으로 스크래핑하기

# %%
html_doc = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Test BeautifulSoup
#   </title>
#  </head>
#  <body>
#   <p align="center">
#    P태그의 컨텐트
#   </p>
#   <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
#  </body>
# </html>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.title), ':', bs.title)
print(type(bs.title.name), ':', bs.title.name)
print(type(bs.title.string), ':', bs.title.string)
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align'])
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs)
# Out:
# <class 'bs4.element.Tag'> : <title>Test BeautifulSoup</title>
# <class 'str'> : title
# <class 'bs4.element.NavigableString'> : Test BeautifulSoup
# -------------------------
# <class 'str'> : center
# <class 'str'> : http://unico2013.dothome.co.kr/image/flower.jpg
# <class 'dict'> : {'src': 'http://unico2013.dothome.co.kr/image/flower.jpg', 'width': '300'}

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[[[ string 속성 ]]]")
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[[[ text 속성 ]]]")
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.text)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[[[ contents 속성 ]]]")
print(type(bs.p.contents), ':', bs.p.contents)
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)
print("[[[ find_all()의 text=True 매개변수 ]]]")
print(bs.find_all("li", text=True))  # 콘텐츠가 텍스트로만 구성된
# Out:
# [[[ string 속성 ]]]
# <class 'bs4.element.NavigableString'> : P태그의 컨텐트
# <class 'NoneType'> : None
# <class 'NoneType'> : None
# <class 'bs4.element.NavigableString'> : 강조
# [[[ text 속성 ]]]
# <class 'str'> : P태그의 컨텐트
# <class 'str'> :
# 테스트1강조
# 테스트2
# 테스트3
#
# <class 'str'> : 테스트1강조
# <class 'str'> : 강조
# [[[ contents 속성 ]]]
# <class 'list'> : ['P태그의 컨텐트']
# <class 'list'> : ['\n', <li>테스트1<strong>강조</strong></li>, '\n', <li>테스트2</li>, '\n', <li>테스트3</li>, '\n']
# <class 'list'> : ['테스트1', <strong>강조</strong>]
# <class 'list'> : ['강조']
# [[[ find_all()의 text=True 매개변수 ]]]
# [<li>테스트2</li>, <li>테스트3</li>]

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p')
print(ptags)
print("----------------")
for tag in ptags :
    print(tag)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>
# ---------------------------------
# <title>Test BeautifulSoup</title>
# <p align="center"> text contents </p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500"/>
# ---------------------------------
# [<p align="center"> text contents </p>, <p align="right">  text contents 2 </p>, <p align="left">   text contents 3 </p>, <p>text contents 4</p>]
# ----------------
# <p align="center"> text contents </p>
# <p align="right">  text contents 2 </p>
# <p align="left">   text contents 3 </p>
# <p>text contents 4</p>

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))

pdom = bs.find('p', align="left")
print("["+pdom.text+"]")
print("["+pdom.get_text(strip=True)+"]")
print("["+pdom.string.strip()+"]")
# Out:
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# -------------------------------------
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# [   text contents 3 ]
# [text contents 3]
# [text contents 3]

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content
print(type(html))
html = html.decode('utf-8')
print(html)
print("==============================")
bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')
print(title)
print(type(title))
print(type(title[0]))
print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
   print(content["src"])
# Out:
# <class 'bytes'>
# ﻿<!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Insert title here</title>
# <style>
#   h1 {
#     background-image : linear-gradient(45deg, yellow, green);
#     height : 80px;
#     text-align : center;
#     font-size : 2em;
#     padding-top : 40px;
#     width : 50%;
#     margin : 0;
#     text-shadow : 5px 5px 5px white;
#   }
#   .subtitle {
#     color : #b30059;
#     background-color : pink;
#     text-align : center;
#   }
#   #f_subtitle {
#     color : #006600;
#     background-color : yellow;
#     text-align : center;
#   }
#   section, aside {
#     width : 50%;
#     border : 2px solid #8000ff;
#     border-radius : 20px;
#     margin-top : 10px;
#   }
#   nav {
#     margin-top : 10px;
#     text-align : center;
#     width : 50%;
#   }
#   a {
#     text-decoration : none;
#     font-weight : bold;
#   }
#   aside>ul {
#      color : #006622;
#      font-weight : bold;
#   }
#   div {
#      background-color :  #003399;
#      text-align : center;
#      color : white;
#      font-weight : bold;
#   }
# </style>
# </head>
# <body>
# <header>
# <h1>CSS 선택자 학습</h1>
# <nav>
# <a href="https://www.w3schools.com/">HTML, CSS, JavaScript 학습 사이트</a>
# <a href="https://www.python.org/">파이썬 학습 사이트</a>
# </nav>
# </header>
# <section>
# <h2 id="f_subtitle">교육과정 소개</h2>
# <div>
# 우리는 파이썬으로 데이터 수집과 전처리 그리고 분석을 학습합니다.
# <img src="https://www.python.org/static/img/python-logo.png">
# </div>
# <br>
# <article>
# <h2 class="subtitle">웹 클라이언트 기술</h2>
# <ul>
# <li id="btype">HTML5</li>
# <li class="atype">CSS3</li>
# <li>JavaScript</li>
# <li class="atype">Ajax</li>
# </ul>
# </article>
# </section>
# <aside>
# <h2 class="subtitle">학습 순서(수집)</h2>
# <ul>
# <li>웹 크롤링</li>
# <li>공공 DB</li>
# <li>SNS</li>
# </ul>
# </aside>
# </body>
# </html>
# ==============================
# [<h1>CSS 선택자 학습</h1>]
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>
# <h1>태그의 갯수 : 1
# f_subtitle이라는 id 속성을 갖는 태그 갯수 : 1
# subtitle이라는 class 속성을 갖는 태그 갯수 : 2
# aside 태그의 <h2> 자식 태그 갯수 : 1
# src 속성을 갖는 태그 갯수 : 1
# CSS 선택자 학습
# ------------------------------
# 교육과정 소개
# ------------------------------
# 웹 클라이언트 기술
# 학습 순서(수집)
# ------------------------------
# 학습 순서(수집)
# ------------------------------
# https://www.python.org/static/img/python-logo.png

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page=1')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
titles = soup.select('.movie')
points = soup.select('td.title > div > em')
reviews = soup.select('td.title')
movie_title = []
movie_point = []
movie_review = [] 

for dom in titles:
    movie_title.append(dom.text)
for dom in points:
    movie_point.append(dom.text)
for dom in reviews:
    content = dom.contents[6] 
    content=re.sub("[\n\t]", '', content)    
    movie_review.append(content)
commentLength = len(movie_title)   
for i in range(commentLength):
    print("영화 제목 : " + movie_title[i])
    print("평점 : " + movie_point[i])
    print("리뷰글 : " + movie_review[i])
    print("-----------------------------------------")
# Out:
# 영화 제목 : 데시벨
# 평점 : 4
# 리뷰글 : 왜 데OO인걸까.. 슬프긴한데 처음 맥락이 안맞네..
# -----------------------------------------
# 영화 제목 : 데시벨
# 평점 : 5
# 리뷰글 : 너무 그저그런 영화... 내용도, 전개도, 연기도 아쉬운 영화입니다.
# -----------------------------------------
# 영화 제목 : 데시벨
# 평점 : 1
# 리뷰글 : 쓰레기 같은 영화 요즘 영화표 값도 비싼데 ^^;; 시간하고 돈만 버리고 왔네요 촌스러운 연출에 난잡한 스토리 왜 좋은 배우들 가지고 이런 쓰레기 영화를  만들었는지 정말 실망이네요
# -----------------------------------------
# 영화 제목 : 자백
# 평점 : 8
# 리뷰글 : 긴장감이 엄청났어요 ! 시간 가는 줄 모르고 봤습니다!
# -----------------------------------------
# 영화 제목 : 인생은 아름다워
# 평점 : 4
# 리뷰글 :
# -----------------------------------------
# 영화 제목 : 동감
# 평점 : 6
# 리뷰글 : 이해는 하지만 동감은 못하겠다.
# -----------------------------------------
# 영화 제목 : 블랙 팬서: 와칸다 포에버
# 평점 : 7
# 리뷰글 : 채드윅 보스만이 살아 있었다면 영화가 어떻게 흘러갔을지 상상이 되서 너무 아쉽고 슬프다
# -----------------------------------------
# 영화 제목 : 심야카페: 미씽 허니
# 평점 : 7
# 리뷰글 : 영화 잘봤습니다 영화 잘봤습니다
# -----------------------------------------
# 영화 제목 : 20세기 소녀
# 평점 : 8
# 리뷰글 : 새드앤딩은 유난히 여운이 오래가요.ㅜㅠ
# -----------------------------------------
# 영화 제목 : 리멤버
# 평점 : 1
# 리뷰글 :
# -----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import re
for n in range(1,31):
    req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page='+str(n))
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie' )
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')
    movie_title = []
    movie_point = []
    movie_review = [] 
    for dom in titles:
        movie_title.append(dom.text)
    for dom in points:
        movie_point.append(dom.text)
    for dom in reviews:
        content = dom.contents[6]
        content=re.sub("[\n\t]", '', content)
        movie_review.append(content)

    commentLength = len(movie_title)   
    for i in range(commentLength):
        print(movie_point[i] + ","+movie_title[i]+","+movie_review[i])
    print("-----------------------------------------------------")
# Out:
# 10,데시벨,진짜 영화관에서 볼 만한 영화라고 생각해요. 돈이 아깝지 않은 구성이었음. 차은우 이종석 비주얼 최고고 사운드도 좀 신경을 많이 쓴듯함
# 1,블랙 팬서: 와칸다 포에버,액션 진짜 빈약하다 후편을 이끌어갈 새로운 영웅들은 포스도 없고 멋도 없음 근데 영화가 길어서 지루하기까지함
# 7,자백,조애욘ㄸ-~~-~-~
# 10,데시벨,간만에 보는 국산 액션 영화
# 1,동감,스토리 최악 개연성 최악 대사 오글 감동도 재미도 설렘도 없는 최악의 영화
# 10,블랙 팬서: 와칸다 포에버,I feel it while watching it, but the music that comes out according to the country's tradition was very sweet, and it was okay to modernize the music style according to the current generation's style. The beauty of each city is also beauty, but most of all, it expresses the condolences of Chadwick Bosman's death in real detail at the beginning and end of the movie. It was a work that I enjoyed watching because I understood the message that the director wanted to give.
# 10,봄,먹먹하고 아련하다..  오랫동안 먹먹할 듯...
# 4,사잇소리,흠... 그냥... 뭐...
# 10,데시벨,영화를 보고 우는 스타일이 아닌데 좀 눈물이 나왔습니다. 첫째는 이종석씨 연기에 놀랐습니다. 최근작부터 이종석씨가 잘생기셔서 보긴했지만 연기에 쪼가 있고 오그라든다는 느낌이 있어서 연기는 잘한다는 생각을 한 번도 못했었습니다. 근데 이종석씨 덕에 무척 중요한 역할이 충분히 몰입되게 한다는 느낌이 들었습니다.한편으로는 안타까웠던건 물론 이태원 사망자들도 많은 아픔이 있겠지만, 나라를 위해 희생한 많은 젊은이들의 복지는 너무 외면되있지 않나 하는 생각도 드는 영화였습니다. 액션도 음향도 연기도 기대보다 너무 만족한 영화였습니다. 이런영화가 흥행했으면 좋겠네요
# 6,오펀: 천사의 탄생,좋아요호허<~
# -----------------------------------------------------
# 10,데시벨,재미 좋다
# 7,킹덤2: 아득한 대지로,전작보다는 전쟁 스케일이 크네요.
# 10,에브리씽 에브리웨어 올 앳 원스,나의 모든 실패를 사랑하는 법
# 10,데시벨,웃다울다놀래다 다했어요 짱짱!!
# 10,데시벨,보는내내 긴장감 넘치는 영화였어요~중간중간 웃음포인트도 있고,마지막에 가슴찡한 스토리까지!!배우들의 연기도 진심 짱^^꼭 보시길요♡
# 10,동감,재미있게 잘 봤어요!! ㅎㅎ
# 10,블랙 팬서: 와칸다 포에버,와칸다 포에버. 채드윅을 가장 우아하게 추모한 영화. 물론 스토리나 영상미도 뛰어나다. 슈리의 앞으로가 기대된다.
# 10,동감,매말라버린 연애세포를 깨우네..
# 8,동감,생각보단 괜찮던데 .. 재밌게 봄
# 10,데시벨,너무 슬프고 재밌고 잘생겼어요 별기대 안 하고 갔는데 생각보다 정말 재밌어서 놀랐습니다 테러액션을 가장한 새드영화!입니다
# -----------------------------------------------------
# 10,노팅 힐,휴그랜트의 연기와 줄리아로버츠의 외모.. 그리고 설레는 설정.. 완벽한 시나리오
# 10,동감,별로라는 사람들이 꽤 많지만..ㅠ 전 너무 재밌었어요ㅎㅎㅎㅎ 한번 더 보러가려구요!
# 8,블랙 팬서: 와칸다 포에버,배우들의 연기는 볼만 합니다
# 8,폴: 600미터,현실적이라고 생각.. 손에 땀을 쥐고 봤다
# 10,데시벨,저는 긴장감 있고..감동도 있고..연출도 좋고 연기도좋고 다 좋았습니다.
# 2,동감,원작을 본 사람은 안보는게 나을듯하다
# 7,파이어버드,중반까지 재밌음 후반이 약함
# 10,데시벨,보는데 너무 눈물났어요 ㅠㅠㅠㅠ 이종석 차은우 환상호흡이 가장 기억에 남네요.이건 꼭 영화관에서 봐야합니다!!사운드테러액션영화 데OO 흥해라>_<
# 2,동감,멜로는 감정선이 보이고 거기에 몰입할수 있어야 하는데….동감이 아니라 ?감이다 전혀 추천하지 않는다 킬링타임용도 안된다
# 7,에브리씽 에브리웨어 올 앳 원스,과정이 ... 보는내내 너무 아프다.
# -----------------------------------------------------
# 7,블랙 팬서: 와칸다 포에버,블랙 팬서1을 안 봐서 막 슬프거나 그러진 않았는데 나쁘지 않았음 근데 좀 루즈한 느낌이 있는 듯 음악이 개쩐다
# 7,블랙 팬서: 와칸다 포에버,주인공이 안타깝게 죽은 와중에서도 제작방향이 급변했음에도 이 정도의 결과는 훌륭하다고 봄. 채드윅 보스만을 마지막 씬은 영화의 모든 단점을 잊게 만들었다.
# 6,블랙 팬서: 와칸다 포에버,개연성없는 스토리와 부족한 정당성과 불필요한 등장인물
# 10,동감,진짜 좋았는데 용이가 너무 불쌍하고 김무늬가 악연인 느낌…… 김혜윤 여진구 잘 어울리더라 드라마 하나 찍어 줬으면 좋겠다!
# 7,앰뷸런스,이정도면 꽤 괜찮은 영화임 킬링타임이 먼지 확실히 보여줌
# 1,해길랍,남주 얼굴말고 남는 게 없는 영화결말 뭐지? 뭔가 있어보이려고 하는데결말이 없는 스토리
# 10,데시벨,일단 깔끔해서 좋다 엔딩에서 좀 과하다고 생각되긴했는데 그 이전엔 꽤 몰입해서 보게되는 영화~! 차은우 이종석 잘생겨서 킬링타임용으로 딱좋음
# 10,데시벨,기대이상이었음.연기력 좋음.
# 10,데시벨,이건꼭봐야하는영화 정말재밌습니다
# 1,블랙 팬서: 와칸다 포에버,마블은 이제 뭐.. PC홍보, 교육물이 됐자너.. 액션 오락 영화에서 PC만세 외치고 있는데 영화가 재미 있을리가 없지
# -----------------------------------------------------
# 10,에브리씽 에브리웨어 올 앳 원스,인간이 영화로 보여줄 수 있는 모든것을 보여준 영화
# 2,데시벨,이게 뭐지 하는 영화;;
# 10,동감,스토리의 반전기대됩니다^^
# 10,데시벨,시간가는 줄 모르고 봤어요 재밌네요
# 7,블랙 팬서: 와칸다 포에버,간지는 있으나 포스는 없는..체드윅 헌정영화 그 이상 그 이하도 아닌
# 10,데시벨,너무 슬퍼요 감정이 느껴집니다.
# 10,데시벨,탄탄한 시나리오인듯,영화기대됩니다
# 6,블랙 팬서: 와칸다 포에버,블랙팬서 너무 말라서 멋이 안 남아이언하트 또봇을 만들어 놈
# 5,데시벨,출연 배우들의 뛰어난 비쥬얼과 열연에도 가려지지 않는 어설픈 전개
# 4,블랙 팬서: 와칸다 포에버,마블영화중에 제일 별로였는데... 블랙팬서 왜케 약해..
# -----------------------------------------------------
# 7,경관의 피,무언가 판타지 같은 느낌이 너무 많이 드는
# 10,블랙 팬서: 와칸다 포에버,그냥저냥그저그럭저럭좋다~
# 10,사잇소리,잘봤습니다.원래 스릴러물을 좋아하는데 소재가 요즘 이슈가 되는 층간소음에 관한내용이라 공감이 잘 갔어요.배우들 연기도 신선했습니다. 다음 차기작도 기대돼요 꼭 보러갈게요!!많이들 봐주셨으면 좋겠어요ㅠㅠ
# 1,동감,진짜 재미없어요....스토리 전개
# 8,분노의 질주: 더 맥시멈,탱크 나오는 장면은 인정!!!
# 10,데시벨,눈물도 찔끔 중간중간 깜놀.. 연기 연출 전반적으로 괜찮았습니다.
# 8,탑,홍상수 감독 영화 세계의 연속과 변주.
# 8,분노의 질주: 더 세븐,차가 비행기에서 떨어지늩 장면은 인정!!!도미닉은 수퍼맨이냐???
# 10,동감,친구들이랑 봤는데 다 재밌다고 그럼!!
# 6,데시벨,김래원, 이종석의 항상 보던 연기, 소재도 그럴듯하고, 조금 질질끌리는 면이 있긴한데 무난한 작품인듯
# -----------------------------------------------------
# 10,데시벨,정말재미있어요♡♡♡♡
# 10,같은 속옷을 입는 두 여자,독입영화가 아닌 영화.상업영화라고 나오는 요즘 영화들 보다 훨씬 잘 만들어진 영화다. 2시간이 넘는 시간동안 힘이 한번도 빠지지 않는다.
# 9,블랙 아담,블랙 아담도 좋았지만 닥터 페이트 미만 잡
# 2,동감,거의 영화 나오기 2달전부터 엄청 기대하고 있었는데 예고편이 제일 재밌음말그대로 영화는 감동도 없고 재미도 없음1999년이라면서배경이 너무 현대 느낌이 많이 났고스토리가 무엇보다 최악임결말은 괜찮았는데 그 속 과정들이이해가 안 가는 장면이 많았고왜 그런식으로 연출했는지 이해가 안 감여태까지 본 영화중에서 제일 실망이었고별로였음
# 8,동감,주인공이  급발진하는게 있긴 하지만, 전반적인 분위기가 좋고, 여진구 목소리, 연기가 다른배우들과는 다르게 독보적으로 좋았다.
# 10,탑건: 매버릭,올해 본 영화 중 최고 ... 아니 2000년대 영화 중 최고....
# 10,기생충,좋은 영화를 판단하는 기준이 또 높아져버렸다. 이 기준은 또 높아질 수 있을 것인가?
# 10,폴: 600미터,재밌게봤다 손에 땀을쥐게한다는부분 인정. 예상치못한 반전있고..
# 10,동감,
# 10,극장판 유루캠△,캠핑가고 싶다
# -----------------------------------------------------
# 8,모터싸이클 다이어리,영화를 보기 전에 체게바라 평전을 한 번 읽어 보면 좋을듯 하다.
# 5,분노의 질주: 더 얼티메이트,스토리가 구질구질하다. 시나리오를  초딩이 발로 썼냐!!!
# 1,동감,영화 개봉하기전부터 광고를 그렇게 하더니 , , , 진짜 재미없어서 그렇게 광고 안하면 아무도 안보러 가니까 그런거구나 . . 진짜 노잼 . . 10점 준 사람들은 알바가 분명해 역대급 재미도 감동도 없음 돈만 너무 아까워
# 6,데시벨,배우들을 괜찮으나... 그 밖의..
# 10,데시벨,전.. 분명.. 액션영화 보러간건데... 왤케 슬픔..? 연기 미쳣습니다.
# 10,블랙 아담,디씨야 이렇게만 하면 좋겠다쿠키는 진짜 웅장하더라
# 9,마이 퍼스트 미스터,보고 나면 가슴이 따뜻해 지는 그런 영화
# 4,블랙 팬서: 와칸다 포에버,채드윅의 부재는 너무 큰 타격이다슈리가 외치는 이범배, 와칸다 포에버는 멋이 없다
# 8,극장판 소드 아트 온라인 -프로그레시브- 짙은 어둠의 스케르초,사운드 너무 작더라.. 액션은 좋던데
# 10,데시벨,배우들 연기가 탄탄해서 안지루하게 재밌게 봤어요. 어느정도 예상가는 스토리지만 긴장감도있고 추천할만한 영화에요!! 큰기대 안하고 봤는데 재밌었어요
# -----------------------------------------------------
# 6,쇼쇼쇼,그냥 가볍게 볼만한 영화
# 10,데시벨,공 포의쓴맛 ~~ 지렸떠영
# 10,동감,원작은 못 봤지만 비교없이 이 작품대로 좋을듯합니다...청순하고 순박함 속에 몽글몽글한 느낌의 산뜻한 영화였습니다
# 8,외계+인 1부,잼있던데... 2부 엄청기다려 집니다.
# 10,블랙 아담,근육이 세상을 구한다...
# 10,데시벨,딘짜너무슬버요진짜개오열함
# 10,드라이브,
# 10,동감,ㅇㅣ거 엄청 재밌는데 다 왜그러는거엽?
# 10,데시벨,
# 10,벌새,잘린 손가락 바라보면서 소주 한잔 마시는 밤 덜걱덜걱 기계소리 귓가에 남아 하늘 바라 보았네 잘린 손가락 묻고 오는 밤 시린 눈물 흘리던 밤 피묻은 작업복에 지나간 내 청춘 이리도 서럽구나 하루하루 지쳐진 내 몸 쓴 소주에 달래며 고향 두고 떠나오던날 어머님 생각하며 술에 취해 터벅 손 묻은 산을 헤매어 다녔다오 터벅 터벅 찬 소주에 취해 헤매어 다녔다오
# -----------------------------------------------------
# 9,에브리씽 에브리웨어 올 앳 원스,
# 10,그 시절, 우리가 좋아했던 소녀,짝사랑의 추억이 떠오르는 좋은 영화입니다
# 8,폴: 600미터,반전이 있는 영화!! 몰입해서 잘 봤어요~
# 10,데시벨,배우들 외모 구경갔지만 스토리도 좋고 연기력도 좋았다
# 7,인생은 아름다워,기승전결 깔끔한 뮤지컬영화네요
# 10,블랙 팬서: 와칸다 포에버,이번에 나온게 더 재미있는것같아요. 너무 억지감동있어서 그랬지만 전작보다는 잼있는것같아요.
# 2,그 남자, 좋은 간호사,지루하고 재미없고 반전도없는 실화영화
# 10,데시벨,연기너무좋고 잠수함씬들이 너무 좋았습니다. 눈물나다가 웃다가 참 재미있게 보았습니다. 마지막장면에서 울었네요 ㅜㅜ
# 2,블랙 팬서: 와칸다 포에버,이 영화까지 망해봐야 디즈니가 정신을 차릴텐데
# 10,블랙 팬서: 와칸다 포에버,빌런이나오는 액션신이 좋았네요  채드윅보스만 기리는점이 너무 좋았습니다.
# -----------------------------------------------------
# 2,동감,은석이랑 한솔이 왜 사귀죠 뭐하자는거지 거북이는 또 왜 쌔벼요? 진짜 빡친다
# 10,킹덤2: 아득한 대지로,액션 하나 하나 공들여 찍은 티가 남, 원작을 본 팬들에게는 최고의 실사화인듯
# 10,헤어질 결심,오랫동안 기다려온 한국 영화의 걸작. 마침내 갈증을 해소해주다.
# 1,블랙 팬서: 와칸다 포에버,진짜 영화관에서 영화를 보면 빵빵한 사운드, 큼지막한 화면, 영화에 집중하기에 맞춘 최적의 분위기 등등 때문에 영화관에서 보는 영화는 웬만해서 재미없기 힘들기 때문에 지금까지 살면서 영화관에서 영화를 보면서 존적이 없는데, 이번에 블랙팬서 보면서 처음으로 졸았음.... 영화보면서 안조려고 노력하는게 진짜 고문인 수준.... 눈이 감기는걸 참으면서 영화를 보는게 진짜 고통임. 진짜 중반에 보면서 그냥 영화비 13000원 버리고 집가고 싶었음. 일단 초반 부분까진 그래도 괜찮았는데 그뒤에 너무 질질끄는듯한 느낌을 주고 이야기 전개를 재미없고 지루하게 품. 그게 한두번이면 괜찮은데 그런 지루하고 질질끄는 연출과 스토리텔링을 심지어 액션씬 제외하고 영화전체의 4분의1정도를 지속시킴. 개인적으로 내셔널지오그래피 다큐멘터리 보는게 이것보다 10배는 재밌었을꺼라고 진지빨고 확신함. 지루한 부분 겨우겨우 다 견디고 중반 액션씬으로 들어갔는데 드는 생각은 '오 좀 예전 마블영화들보다 뭔가 잔인해졌다.... 아프겠다...' 이생각밖에안들고 멋지단 생각이 1도 안듦.  마지막에 블랙팬서로 여주인공이 변하는거 보고 그전까지 걱정했던 부분이 그대로 적중함. 일단 여주인공이 키에 비해서 몸이 너무 말랐고 잔 근육도 없는데 꽉 끼는 쫄쫄이인 블랙팬서 슈트를 입으면 그게 더더욱 부각되서 정말 구라안치고 나무젓가락위에 블랙팬서 헬멧 올려놓은거같음. 툭치면 부러질꺼같음. 시빌워랑 블랙팬서 1에서 채드윅 보스만이 보여준 블랙팬서 슈트를 입었을때 적당한 근육질몸매가 멋있는 슈트와 잘 조화를 이뤄서 진짜 야생의 표범을 보는듯한 느낌은 온데간데없고 한대 치면 날아갈꺼같은 빼빼마른 몸이라 멋이 1도 안나서 블랙팬서가 처음으로 슈트 입고 하늘에서 등장하는 씬에선 오히려 웃음이나옴. 심지어 그런 빼빼마른 몸에서 적이 한대치면 다 날아가는 말도 안되는 무지막지한 힘이 나오니깐 어떤 액션을하든 오히려 너무 의구심이들고 멋있지도 않고 임팩트도 없음. 차라리 음바쿠한테 블랙팬서 억지로 시키는게 나았을 수준
# 7,동감,특유의 오글거림을 좋아하는데 ㅎㅎㅎ 연애비수기인 사람에게도 느껴지는 설레임이 좋았다... 그만큼 주인공들의 푸릇푸릇한 느낌이 전해진거 같기도.. 몇몇 이해되지않는 스토리? 연개성, 아쉬움등으로 7점...!!
# 7,바르도, 약간의 진실을 섞은 거짓된 연대기,오랜만에 느끼는 압도적인 시각 경험
# 5,동감,이건 로맨스가 아니지 않나..? 이루지지 않은 사랑이 왜 로맨스인지 이해가 안돼네요.. 김용이 너무 불쌍해서 못보겠어요… 초반까지는 러브라인 타다가 갑자기 중후반부터 친구부터 여주가 쓰레기가 되는게 좀 ..
# 7,동감,재밌어요그리고 여진구 배우님도 너무 잘생겼어요
# 7,자백,예측가능한 전개와 김윤진배우의 몰입감있는 연기력
# 6,데시벨,선택에 관해 한 번쯤 생각해볼 시간을 갖는데 의의가 있을 뿐
# -----------------------------------------------------
# 2,블랙 팬서: 와칸다 포에버,블랙팬서 무한~ 무야호
# 10,블랙 팬서: 와칸다 포에버,케빈파이기도 한물 간듯 이딴걸 영화로 만들었냐 채드윅 보스만 추모 기간이 지난지 언젠데 지금 나오냐
# 1,심야카페: 미씽 허니,
# 9,폴: 600미터,볼 만해요!!! 그런데 상영관이 별로 없네요. 아 거지 같은 충무로 마피아들.
# 10,데시벨,넘재밌네요 이종석연기 넘잘해요
# 10,폴: 600미터,중간에 반전.. 소름끼쳤음 기대했던 것보다 훨씬 재밌고 또 보고 싶음
# 10,인간중독,
# 10,동감,풋풋하고 귀여웠어용 꿀잼
# 10,변호인,재미있습니다 제 인생작 입니더
# 10,변호인,재미있습니다 제 인생작 입니더
# -----------------------------------------------------
# 10,폴: 600미터,몰입이 잘돼서 시간가는줄 모르고 봤다. 재밌고 스릴있다.
# 10,폴: 600미터,초등학생이랑 보면 좋을 것 같아요 짱잼bb
# 10,동감,후유증이 남는 영화너무 재밌었어요!
# 10,심야카페: 미씽 허니,마지막에서 포텐 터지네요... 추철민? 추철인? 누군지 너무 궁금할 정도로 연기 너무 좋아요 중간에 익숙한 광안리? 부산에서 촬영했다는데 여행 가고 싶어져요재밌습니다
# 10,동감,영화 마지막 부분부터 계속 쭉 눈물이 났어요.. 너무 감동적이고 영화 너무 공감되고 잘 만들었어요.. 다들 꼭 보시길 추천드립니다!!
# 10,동감,원작을 안봐서 원작내용을 모르지만진짜 재밌는데  왜이렇게 낮은지 모르겠네여
# 1,뜨거운 피,너무 급하게 나왔다... 개인적으로 소설 스무번넘개 정독하며 본사람으로써 아미라는 인물을 좋아하는데  인숙 과 아미 의 캐스팅 그리고 원작과 다른 아미의죽음 원작과 다른 스토리 ... 아..  진짜 짜증난다 감독 이 원망스럽다 이렇게 만들거면 그냥 만들지말지 ..  다른 감독님이 리메이크한번 시원하게 해주면좋겠다..  정우는 너무 젊어보여서 몰입이안되고 차라리 황정민 을 캐스팅하지.. 아 돈이문제였을수도있겠구나..  그럼 만들지말지그냥
# 10,데시벨,이종석사랑해감사합니다꼭보세요
# 8,블랙 아담,기대안해서 그런지 생각보다 괜찮았다. 주연보다 조연이 빛나는 영화
# 10,동감,처음엔 김용이  너무 웃겨서 좋았고 조이현은 너무 예쁘고  그래서 한번더 볼 예정입니다
# -----------------------------------------------------
# 4,해피 뉴 이어,스토리가 너무 뻔하고 마인같았음.한지민 얼굴만 볼만한 영화
# 9,동감,원작의 열혈팬이다. 그래서 기대를 많이 내려놓고 보러 갔는데^^ 그에 비해서는 선방한 리메이크작 이었다. 앞으로 한국 로맨스 영화가 부흥하기를 바라게 된다. 여진구 조이현의 순수한 연기란.
# 10,데시벨,예고편은 예고편 일 뿐  반전매력 !! 나는 그게 좋았다 직관해야 알 수 있는 영화 !!!
# 10,데시벨,배우들 연기력이 진짜 오짐. 특히 이종석ㅇㅇ 차은우 잘생김. 차은우 연기 걱정했는데 잘해서 볼만했음. 액션인데 서사(?도 좋아서 액션 안 좋아해도 보기 좋은 듯.슬픈 장면이 있긴 해도 신파까진 아니라 좋았음. 추천ㅇㅇㅇㅇ
# 6,데시벨,잘보긴 했어요 음,,
# 10,데시벨,너무 감동적인 영화… 여운이 너무 남아서 미치겠음
# 8,데시벨,돈 아깝다는 생각은 안 들고, 영화가 알찬 거 같아요 (여성, 21세, 일반인)
# 1,데시벨,알바 좀 작작 풀어라 제발
# 10,데시벨,정말 재밌게봤습니다!
# 8,블랙 팬서: 와칸다 포에버,영화 스토리가 좋아요
# -----------------------------------------------------
# 8,같은 속옷을 입는 두 여자,야심에 걸맞는 재능이 돋보이는 훌륭한 데뷔작이었다. 보통 이정도까지 밀어붙이면 중반부 이후나 엔딩이 이르러서는 인물이나 영화가 무너지는 경우 정말 많은데 이 영화는 적당히 타협하지 않으면서 두 인물을 대책없이 옹호하거나 미워하지 않게 한다. 특히 세심한 인물 설정을 연출로 뒷받침하는 부분들이 정말 좋았는데 초반에 휴대폰 앨범에 어린이 서적만 가득한 장면 이후에 차 안에서 어머니에 의한 무지막지한 폭력을 받아내는걸 보여줘서 당연히 청소년이라고 생각했는데 이후에 20대 중후반으로 설정된 인물이라는걸 알게된다. 이건 영화의 주요한 메시지와도 연결되는데, 이런 섬세한 연출이 영화 전반에 가득하고 이내 엔딩에 이르러서 그 울림을 극대화시켜준다.가스라이팅, 학대, 감정의 쓰레기통, 폭력, 정신병 등 이런 관계에서 수반되는 모든걸 전혀 피해가지 않으면서도 인물들이 기능적이지 않다는건 정말 대단하다고 생각한다. 게다가 주역뿐 아니라 영화에 등장하는 모든 인물이 너무나도 생생하지만 튀지 않고 영화속에서 자신의 삶을 살고 있다.그렇게 모진 말을 쏟아내고도 서로 명시적인 사과를 하지 않고 관계를 이어가는 수경의 삶과 제발 사과 한 번만 해달라고 무릎 꿇고 울분을 쏟아내는 이정의 삶의 대비가 너무 적확해서 아직도 아프다. 이제서야 혼자 서게 된 이정이 서로의 마음을 제대로 나눌 수 있는 관계를 만들 수 있으면 좋겠다.
# 10,동감,몽글몽글하다는 단어를 가장 잘 설명한 영화ㅠㅠ 풋풋하고 설레고 귀엽고 예쁘고 다함.. 반전에서 결말까지는 눈물닦아가면서 봤어요ㅠㅠ 강추강추
# 10,첫번째 아이,영화가 아니라 다큐멘터리 같았어요. 지독한 현실 고발…
# 8,동감,
# 10,데시벨,스토리 굿 캐스팅도 아주 좋았음
# 10,데시벨,후반부 보고 우는 사람도 많았음.. 배우진부터 대박인데 다들 연기 너무 잘했고 이종석-차은우 서사가 진짜...소리에 반응하는 소음 폭탄이라는 소재가 엄청 신박했던 것 같다.
# 10,데시벨,초반에는 엥 뭐지 하며 보다가, 점점 몰입되며 너어무 재밌더라구요!!!! 마지막에 진짜 스토리 확 풀리며 오열… 최고입니다
# 7,데시벨,다이하드 4가 생각나며억지감동 유발
# 1,블랙 팬서: 와칸다 포에버,개연성 떨어짐, 액션 별로, pc
# 10,동감,
# -----------------------------------------------------
# 2,데시벨,두가지 놀란점 .. 발연기에 놀라고 평점에 다시한번 놀람 ㅋㅋㅋ
# 10,똥파리,인물들간의 얽히고 설킨 관계가 지독하리만치 날카롭고 쓰라렸다 모든 배우들의 열연과 표현력에 박수를 쳐주고 싶다 똥파리는 수작이다
# 10,공조2: 인터내셔날,윤아 너무 사랑스럽고 예쁘다
# 10,데시벨,영화 너무 재밌게 잘 봤습니다.
# 8,데시벨,사운드와 영상미가 극장으로 보니까 볼만하군요
# 1,블랙 팬서: 와칸다 포에버,내용 1도 없고, 감동도 없다
# 10,데시벨,진짜 최고였다… 배우들도….내용도…
# 10,데시벨,평점보고 볼까말다하다가 봣는데 꿀잼이엿슴
# 8,블랙 팬서: 와칸다 포에버,그런데로 볼만한 데 상영시간이 길다.
# 10,데시벨,평점 잘안남기는데, 영화보면 뻔할 것 같지만 연기나 스토리 진짜 잘만들었어요.또 슬프고 내용도 알차게 재밌게 봤어요. 진심이에요 봐보세요
# -----------------------------------------------------
# 2,동감,영화은 배경 이쁨근데 기대만큼 내가 영화를 동감하면서 보지는 못함
# 10,동감,너무재미있었습니다 감사합니다!
# 10,데시벨,슬플거라곤 생각도 못했는데 보다가 울었네요ㅜ 배우분들 연기가 다 너무 좋았어요
# 10,동감,원작도 봤는데, 너무 재미있었어요!
# 10,동감,조이현씨의 연기가 좋았고여진구씨가 떠나는 이유가 자기가 미래를 바꾸면안된다는 이유가 있는거같고 사랑을 포기한다 라는것이 쉽진 않았을텐데 되게 슬프면서도멋진거같습니다.
# 10,데시벨,
# 10,데시벨,말이필요없네요 보세요!!!!
# 10,데시벨,몰입도 짱이었습니다! 너무너무 잼있었습니다
# 1,블랙 팬서: 와칸다 포에버,카봇도 이렇게 만들면 욕먹어요..템퍼에서 안봤음 걍 나왔음
# 4,인생은 아름다워,유치한 게 매력으로 남는  영화
# -----------------------------------------------------
# 1,블랙 팬서: 와칸다 포에버,노잼노잼노잼노잼노잼노잼노잼
# 8,엑소시스트: 디렉터스 컷,역시 명작은 지금 봐도 너무 좋다. 굿굿
# 10,데시벨,출연배우들이 각각 역할에 잘 어울리고 이종석배우 성장햇네요
# 8,폴: 600미터,친구도 잘 사겨야....
# 10,데시벨,무조건 극장가서 봐야 합니다. 긴장감, 영상미와 마지막 반전 감동까지 절대 후회하지 않을 작품입니다. 옆에 친구와 잡담을 시간이 없이 몰입해서 봤습니다.
# 1,블랙 팬서: 와칸다 포에버,감독이 벌레면 명배우로도 할 수 있는게 없구나... 다른 감독이였으면 평점 9점대로 올라가겠다..
# 9,동감,영화 보기 전에 원작을 봤는데 확실히 시대감 부분에서 연출이 좀 많이 아쉽긴 했는데 요즘 애들이 약속이 있다고 비 맞고 기다리는 건 좀.. 아무리 리메이크라 미래 사람이 맞고 있는건 그렇다쳐도 너무 억지가 아니였나..싶은 마지막에 우산주는 씬으로 커버를 쳤다고 해도 그분분은 좀.. 아무튼 이부분 빼고는 리메이크라 기대하고 봤는데 새로운 동감 느낌을 받아서 좋았고 배우분들 연기에 아주 감명을 받았습니다 과거의 작품을 좀더 풀어서 연출한 점이 너무 좋았습니다. 리메이크 해주셔서 감사합니다 잘봤습니다!
# 10,동감,조이현 나온다고 해서 봤는데 너무 재밌었어요 꼭 보세요~~
# 8,데시벨,재미있게 잘 봤습니다!
# 8,블랙 팬서: 와칸다 포에버,주인공이 사망했으니 3탄을 이어가기 위한 빌드업이라고 생각하면 재밌어요.하지만 액션만 생각하면 기대이하입니다.저는 이해하기로 했어요...ㅎ
# -----------------------------------------------------
# 4,동감,내용은 그냥 그런데 대사들이 오글거려요로맨스 장면도 억지스러운 느낌?
# 7,블랙 아담,영상미는 좋은데 약간 유치해요
# 10,동감,캬  풋풋한 감성을 오랜만에 느낄수 있어 좋았습니나^^
# 1,폴: 600미터,진짜 이딴걸영화라고만들엇냐블랙폰이랑 이게제일돈아깝게본영화임둘다무슨죽은사람이분신술써서대화ㅋㅋ아니 무슨 처음부터드론을갖고올라가든지그리고저걸왜올라가? 그리고무슨 폭풍왓는데어떻게살아잇어?대머리독수리는그리고왜자꾸나와ㅋㅋ그리고 감동도없고찝찝하고 무슨 죽기만하면영화인가ㅋㅋ 그리고가더라도내려올땐 스카이그 전쟁때쓰는패러글라이딩같은거가지고갓어야지 기본인데 다음부터는 스카이다이빙하면서 비행기에서쓰는거 그거꼭챙겨서올라가게해라 안죽는다이딴걸로sas애들은 비행기 상공 1000m에서뛰어서 전쟁참가한다 이영화는진짜억지임 저길왜올라가?
# 8,블랙 팬서: 와칸다 포에버,재밌게 봤습니다.이번 영화는 오락성하고 대중성 보다는 배우의 추모와 가상국가의 성장에 초점을 맞춘것이 보였고 스토리나 개연성은 그렇게 나쁘지 않았다고 생각합니다.하지만 아이언하트는 확실히….
# 1,심야카페: 미씽 허니,하고 싶은게 너무 많아서 스토리가 완전 짬뽕 됐는데 연기력도 안 받쳐줌... 이이경 정영주 나오면 숨통이 트여요 그림은 그래도 예쁜 편인데 스토리도 연기도 후시도 총체적 난국
# 1,남산의 부장들,자유민주주의체제를 지키기 위해 반공을 한것을 독재로 포장하고 선동하는 악당들이야말로 이 시대에 적폐다...공산화세력들로부터 대한민국을 지켜낸 박정희대통령이야말로 민주화의 주역임...
# 10,블랙 팬서: 와칸다 포에버,3편을 위한 2편인듯? 좋았다
# 10,동감,나빼고 남자는 다 늑대다~  연애에 친구 원수는 없다
# 8,데시벨,재밌었다 뽑기 너무 슬퍼유ㅠ
# -----------------------------------------------------
# 10,데시벨,김래원, 이종석, 차은우 bb
# 7,키드,우린 얼마나 많은것을 잊고 살아가는지...
# 10,데시벨,잘생긴 배우분들 많이 나와서 눈호강 했어요액션영화 인줄 알았는데 슬픈여운이 남는 영화였습니다차은우 짧은머리 너무 잘 어울렸어요삶과 죽음 사이에 과연 인간으로서 현명한 선택을 할수있을지 스스로 생각해볼 시간이였던거 같습니다재밌게 잘 봤어요
# 7,크로우,개봉할때 보고 싶었는데 이제서야 봤다.
# 8,동감,첫사랑은 이루어지지 않는다는걸 .. 초반에 좀 지루했으나 볼만했던 영화
# 10,데시벨,몰입도 너무 좋게 봤어요 !배우들 연기도 잘하고 중간중간 눈물날뻔 했어요
# 10,동감,40대에 오랜만에  느끼는  20대때  감성이였습니다.간질간질하고  입꼬리가  올라가네요  울  아들들이  그럴까  하고   감정이입이 되기도하구요
# 8,콜 오브 와일드,벅이 사람보다 낫네.
# 4,데시벨,차은우가 이종석 동생이라는 설정이 너무 늦게 밝혀져서 개연성부족. 이름이 비슷한건 알았는데요. 김래원배우의 고뷰분투가 버겁게 느껴졌음
# 10,데시벨,배우들 연기가 멋지네요. 몰입해서 봤습니다.
# -----------------------------------------------------
# 10,동감,옛날생각이 많이났어요연출님으 츄파츕스 갬성 좋아좋아
# 9,엑소시스트: 디렉터스 컷,재개봉해 준 덕분에 명작을 극장에서 관람할 수 있었습니다.
# 8,동감,무난했음, 1점짜리 영화까지는 아님
# 8,블랙 팬서: 와칸다 포에버,너무 슬퍼서 울었어ㅜㅜ 액션씬좋고 배우들 너무 조았어요
# 1,데시벨,정석대로 공부한 사람이 무섭고, 정석대로 운동한 사람이 무섭듯 정석대로 쓰레기 영화를 만들면 파괴력이 굉장하다. 데OO에서 데는 묵음처리 해도 된다.
# 10,킹덤2: 아득한 대지로,켄토 때문에 킹덤1 봤다가 료에게 반하고 료 때문에 킹덤2 기다렸다가 다시 켄토에게 반하고.. 둘다 너무 멋지고, 역시 이런 스케일의 영화가 제 마음을 사로잡네요!! 빛나는 영정의 첫 등장, 신의 질주와 도약, 왕기의 갑작스러운 등판, 강외의 통통 점핑 장면이 가장 인상적이었습니다. 강외는 적으로 두지 말고 친하게 지내야 함^^ 엔딩곡도 끝내줍니다
# 10,극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교,내 청춘을 어떻게 보낼까
# 8,동감,나도 미래에서 사는분과 교신해서 로또번호나 알려줬음 좋겠다...ㅠㅠ
# 10,서칭 포 슈가맨,내용 뿐 아니라 감독의 일까지 들으면 더욱 충격인 영화. 다큐도 이렇게 재미있을수 있구나라는 생각이 들게 한 영화 반전 있는 다큐라니..
# 2,블랙 팬서: 와칸다 포에버,그냥 재미없고 마블은 끝난듯; PC + 근본없는 아이언하트…
# -----------------------------------------------------
# 10,데시벨,
# 10,심야카페: 미씽 허니,웹드라마의 극장판이라는 특징이 잘 드러나는 영화입니다.
# 10,동감,재밌게 봤습니다. 보기 좋네요
# 8,데시벨,내용은 흥미로웠어요. 뽑기 할 때는 마음이 안 좋았어요.
# 8,데시벨,몰입해서 재밌게 봤음
# 10,동감,와 진짜 인생 영화임 스토리 전게가 개쩜
# 10,명탐정 코난: 감청의 권,코난은 팬심으로 보네요
# 10,가재가 노래하는 곳,영화속 책 갖고 싶습니다. ㅎㅎ여주님 영화 찾아봐야지
# 10,퍼펙트맨,이렇게 슬픈 영화인줄 몰랐어요. 감동적이네요.
# 10,동감,보길 잘했네요  마음이가는대로 라는 대사를 보고 저도 그렇게 하기로 했습니다
# -----------------------------------------------------
# 10,동감,첫사랑의 풋풋함~ 아련하고 좋았어요! 영화라서 스토리가 뚝뚝 끊기는 느낌은 받지만요 한솔이랑 용이가 뒤에서 진짜 서로 좋아하고 있던건지..? 이런 부분이 조금 더 풀렸으면 어땠을까 싶네요 저도 잘되고 싶은 인연이 있는데 현실적으로 안될 것 같아서 포기하려해요 용이처럼 그렇게 떠나 보내지 않을까싶네요ㅠㅠ 마음 같아서는 무늬처럼 남사친에게 멋지게 고백하는건데!! 쉽지 않아요ㅎ.ㅎ 아무튼 영화보는 내내 풋풋함과 가슴이 아련한 행복한 시간이였습니다!!
# 10,폴: 600미터,오랜만에 긴장감 가득한 영화 봐서 만족합니다. 짜릿했어요.
# 10,블랙 팬서: 와칸다 포에버,리리 슈트를 보고 아이언맨을 대체하려 발악한다고 하는 사람들은 어떻게 책 읽고 이해하세요? 그냥 딱 봐도 스타크 인더스트리 도면만 보고도 만들 어 낼 수 있을 정도인 리리의 천재성을 보여주기 위한 장치일 뿐이고 이번 영화에서 리리가 도움이 되기 위한 슈트일 뿐 리리의 정체성이 아닌데…
# 10,데시벨,너무 감동 배우들이 연기도 잘하고 액션도 멋지게 해서 감탄 하였습니다
# 10,데시벨,믿고보는 김래원!! 배우분들의 연기가 아주 좋았습니다 마지막까지 눈을 뗄수가없었네요스토리도 좋았고 연기도 좋았고 굿
# 10,폴: 600미터,영화 보는 내내 박진감이 넘쳐 손에 땀이 나는 영화는 처음이였습니다!! 긴박한 상황이 계속 이어져서 시간 가는줄 모르고 집중해서 봤습니다. 긴장감과 스릴이 있어 몰입감도 최고였습니다. 반전이 있어 소름 돋았고 무엇보다도 스토리가 너무 탄탄하고 배우분들의 연기력 최고…!!! 앞으로 더 좋은 영화 만들어주셨으면 좋겠습니다 :)
# 8,내 친한 친구의 아침식사,청춘 영화는 대만이라고 해서 봤어요. 재미 있었습니다.
# 10,동감,그 시절을 떠올리게 하는 감성, 그리고 있을법한 용이라는 캐릭터와 그의 고민을 함께 나눌 수 있는 영화라고 생각합니다 여진구 배우의 연기도 매우 좋았어요
# 10,블랙 팬서: 와칸다 포에버,
# 2,동감,진짜 뭘까.. 뭐지 이거 예고랑 너무 다른데…
# -----------------------------------------------------
# 10,캡틴 아메리카: 윈터 솔져,히어물이 아님, 첩보물임
# 1,사잇소리,여자 주인공 진짜 짜증나는 발연기 하나로 끝.
# 8,미시즈 해리스 파리에 가다,예쁜 옷 보고 힐링했어요
# 8,킹덤2: 아득한 대지로,빨리 주인공 신이 천하대장군이 되는 모습을 보고싶을 뿐이다
# 1,인류멸망보고서,보고 화난영화는 이게 처음인데 작중에서 화날만한걸 제공한게 못만들어서 화가났음포스터에 속았다 ㄹㅇ 에피소드 3개있는데 두번째가 젤 재밌었고 나머진 분리수거못함
# 10,블랙 팬서: 와칸다 포에버,너무 기대 안하고 봐서 그런지 진짜 잘 봤어요 서사도 괜찮고 공백도 충분히 잘 채웠다고 생각해요아마...진짜 토르랑 닥터에서 모든 기대를 버려서일지도
# 10,블랙 팬서: 와칸다 포에버,너무 기대 안하고 봐서 그런지 진짜 잘 봤어요 서사도 괜찮고 공백도 충분히 잘 채웠다고 생각해요아마...진짜 토르랑 닥터에서 모든 기대를 버려서일지도
# 10,블랙 팬서: 와칸다 포에버,너무 기대 안하고 봐서 그런지 진짜 잘 봤어요 서사도 괜찮고 공백도 충분히 잘 채웠다고 생각해요아마...진짜 토르랑 닥터에서 모든 기대를 버려서일지도
# 10,블랙 팬서: 와칸다 포에버,너무 기대 안하고 봐서 그런지 진짜 잘 봤어요 서사도 괜찮고 공백도 충분히 잘 채웠다고 생각해요아마...진짜 토르랑 닥터에서 모든 기대를 버려서일지도
# 10,폴: 600미터,진짜 꼭보세요!..하 인생 최고의 스릴 극강의 긴장감 이였습니다ㅜ저 알바아님 ㅠㅠ진짜 꼭보세요ㅠ존잼!
# -----------------------------------------------------
# 5,데시벨,그냥 저냥 했네요
# 6,데시벨,허술하고 어이없는 전개에 다른 장점들이 모두 묻힌다.
# 8,블랙 팬서: 와칸다 포에버,액션만 조금더좋았으면 완변했을듯
# 8,동감,현재와 과거의 청춘의 설렘과 안타까움, 뒤에 뭔가 더 엄청난 사연이 있을것 같았지만 없어서 조금 아쉬웠다.
# 1,데시벨,천안함이 계속 생각나네...그리고 어뢰가 계속 대한민국꺼라고하는거 보면 ㅋㅋㅋ 그 음모론이 맞다는거냨ㅋㅋㅋ
# 8,동감,배우들 연기는 좋은데 몰입이 잘 안됩니다.
# 8,공조2: 인터내셔날,시간이 잘 갔어요. 이 영화의 존재목적은 잘 한거겠죠
# 10,매트릭스,존재에 대한 의심은 영화를 여기까지 발전시켰다.
# 4,데시벨,기대이하 예고편은 재밌어보이던데..
# 10,데시벨,연기들 너무 좋았고 중간중간 개그도 좋았어요!!  지루할틈 없이 몰입해서 봤어요
# -----------------------------------------------------
# 10,동감,조이현배우 연기가 좋았다
# 9,클래식,이뤄지지 않은 첫사랑은 현재로 돌아와 새사랑으로
# 2,데시벨,내가 도대체 뭘 본거지…
# 10,데시벨,
# 1,블랙 팬서: 와칸다 포에버,기존 작품에서 쌓아온 신뢰를 다 떨어뜨립니다Pc 페미니즘으로 물든 역겨운 작품
# 10,리멤버,흥행을 못한 이유를 모르겠네 싶을만큼 좋았다 올해 쭉 여운이 남는 영화로 생각된다 강추하고싶다
# 10,수프와 이데올로기,막연히 남의 얘기라고 생각했던 일이, 추운날 뜨끈한 삼계탕 국물 첫 숫가락 먹을때 처럼 목구멍을 타고 내 속을 쿡쿡 적셨다
# 3,동감,와 나인우 연기 왜이럼?? 너무 당황스럽네..  주연배우들 중 제일 붕뜨고 나잇대도 혼자 안맞는 느낌 조이현이랑 아무리 봐도 친구로 보이지않음 영화는 오글거리지만 볼만함
# 4,데시벨,굳이  그렇게해야 속이 후련했냐 라고 그목소리 듣고싶었다
# 10,데시벨,처음부터 흥미진진초반엔 지루할 수 있었던 소재인데도처음과 끝까지 손에 땀을 쥐게 한 영화ㅠㅠ너무 재밌게 봤습니다
# -----------------------------------------------------
# 2,데시벨,돈과 시간을 버리셨습니다.. 좋은 배우들로 안타까운 스토리;
# 2,동감,솔직히 연출 별로임..
# 10,데시벨,김래원, 이종석, 정상훈 모두 연기 괜찮고 옆에 있는 와이프는 울었네요~많은걸 생각하게 하는 영화였습니다. 강력 추천합니다~
# 2,블랙 팬서: 와칸다 포에버,
# 1,동감,
# 6,자백,좋은 원작에 훌륭한 각색이 돋보입니다. 원작을 모르고 봤으면 더 재미있었을 것 같아요
# 10,동감,예전생각도 많이나고 영상음악연기  특히여진구연기넘좋았어요. 지금막보고 왔네요. 맘이 몽글몽글해졌어요. ^^
# 10,동감,너무 재밌게 잘봤어요 다들 연기너무잘함
# 10,에브리씽 에브리웨어 올 앳 원스,최고입니다 인생영화가 되었습니다완벽한 멀티버스 영화이자 양자역학에 대한 좋은 예시라고 생각합니다
# 5,블랙 팬서: 와칸다 포에버,채드윅의 빈자리를 채우기 위해 여러 인물을 무리하게 내놓으며 분발했지만 너무 과했고 빈자리는 더 크게 느껴졌다
# -----------------------------------------------------
# 10,블랙 팬서: 와칸다 포에버,최고의 배우를 잃은 상황에서 만들수있는 최고의 영화
# 10,블랙 팬서: 와칸다 포에버,솔직히 개인적으로 블랙팬서 수트 빼고 새로나온 수트들 다 촌스럽다고 생각하긴함. 그리고 스토리에 너무 많은걸 담아서 분산되는 느낌이 살짝 있는데 다 스토리에 넣을만한 이야기여서 이해해줄수 있음. 중간에 악당서사 나올때 지루하긴한데 이야기의 이해도를 위해 어쩔수 없다 생각하고 뒤에 전투씬이 모든걸 해결해줌.슈리가 블팬됐을 때 진짜 개좋아서 소름돋았다. 블팬만의 오묘한 분위기의 느낌이 여전히 좋다.마지막으로 초반하고 마지막에 진짜 울뻔했어 채드윅 보스만을 헌정하기 위한 영화라는 본질을 잊지 않아서 좋음.
# 6,데시벨,기대를 안하고 보면 재밌지만 기대하고 보면 쏘쏘…그래도 연기력은 최고
# 10,극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교,너무 재밌고 너무 감동적입니다.
# 10,블랙 팬서: 와칸다 포에버,넘 재밌게봤는데... 제가 수준이 낮은건가봐요...하하
# 10,데시벨,ㄹ ㅔ ㅈ ㅓ ㄴ ㄷ ㅡ 얼굴이 다했네
# 10,블랙 팬서: 와칸다 포에버,음악이 너무 소름돋게 잘어울리네요
# 10,알 포인트,장면마다 사람 머리수 세는 재미도 있음다시 볼 때마다 포인트를 발견하는 영화임
# 6,데시벨,음…그냥 킬링타임용…배우가 아깝다고 느껴지고…내용이 너무 부실하다는 생각뿐…
# 2,블랙 팬서: 와칸다 포에버,돈아깝다  웬만하면 후기 안남기는데
# -----------------------------------------------------
# 9,한산 리덕스,이야기가 풍부해진 만큼 각 인물들과 서사의 설명도 그만큼 자세해졌다. 미역 먹방이 이번에도 편집된 것은 좀 아쉽다...
# 10,동감,영화 너무 좋았어요 끝나고도 여운이 남았어요
# 8,블랙 팬서: 와칸다 포에버,스토리면에서 나쁘지 않았음 스케일도 좋았음
# 10,동감,심플해서 좋았어요 욕심껏하자면 한도끝도 없겠죠 욕심없이 있는그대로 심플하게 깨끗하게담아낸 영화 가끔 이런 느낌도 우린 필요하지않을까요  굿
# 1,블랙 팬서: 와칸다 포에버,아니 무슨 중국 히어로물임?
# 10,데시벨,
# 10,47미터 2,ㅠㅠ미쳣음..진심 한순간도 긴장을 놓친적없는 영화
# 4,블랙 팬서: 와칸다 포에버,제발 그만 질질 짰으면 좋겠다
# 10,데시벨,김래원배우님 역쉬 최고였습니다그외 연기자들 박빙넘치는 숨막히는 연기력 과탄탄한스토리까지 ~ 이런영화는 꼭 극장에서 보시길 추천합니다리더의 결단력 그렇게 할수밖에 없었던 그 마음연기들 넘 잘 했어요 강추합니다!
# 9,심야카페: 미씽 허니,기대없이 봤는데 중반이후부터 잼있었네요 킬링타임급은아니고 영화관서 볼만함 8점인데 내가좋아하는배우나와서 1점추가~
# -----------------------------------------------------
# 6,데시벨,전제척인 내용이 허술함 하지만 재밌음
# 6,동감,원작은 모름에도 안일함이 느껴진다.
# 10,블랙 팬서: 와칸다 포에버,슈리 처음 수트 입고 뛰냐리는 장면 보고 쌀뻔했다
# 10,언더 워터,개무섭고존니재밌음...
# 6,동감,음악이라도 좋을까 싶었는데..딸손에 이끌려 잠시동안 옛날갬성 이였습니다
# 2,동감,뭐지??!??!??!
# 10,데시벨,정말 믿고보는 배우들의 연기다보고나면 묘한 감정이 들고슬픈 영화너무 재밌게 봤습니다데OO 대박나길??
# 8,외계+인 1부,제법 볼만합니다폭망정도까지는 아니던데
# 4,블랙 팬서: 와칸다 포에버,너~~~무 길어 할 말은 장황한데 재밌지는 않다
# 10,데시벨,끄야야야야 완전 최고 입니다 .. 진짜
# -----------------------------------------------------

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd


titles = list()
summaries = list()
ratings = list()

for page_num in range(1,21):
    url = f"https://comic.naver.com/genre/bestChallenge.nhn?&page={page_num}" 
    req = requests.get(url)
    
    html = req.content.decode("utf-8")
    bs= BeautifulSoup(html, "html.parser")
    
    for info in bs.find_all(class_="challengeInfo"):
        titles.append(info.find(class_="challengeTitle").a.text.strip())
        summaries.append(info.find(class_="summary").text.strip())
        ratings.append(info.find(class_="rating_type").strong.text.strip())
    print(f"{len(titles)}개 추출")
    
naver_comic_dict = { 'title':titles, 'summary' : summaries, 'rating' : ratings }    

df = pd.DataFrame(naver_comic_dict)
display(df)

print(reviews[0].contents)
# Out:
# 24개 추출
# 48개 추출
# 72개 추출
# 96개 추출
# 120개 추출
# 144개 추출
# 168개 추출
# 192개 추출
# 216개 추출
# 240개 추출
# 264개 추출
# 288개 추출
# 312개 추출
# 336개 추출
# 360개 추출
# 384개 추출
# 408개 추출
# 432개 추출
# 456개 추출
# 480개 추출
#             title     summary rating
# 0            이딴여행       여행포토툰   9.79
# 1        과학고 생존일지  과학고에 간 문과생   9.81
# 2          고인물 연애  15년차 커플 일상   9.81
# 3    마피아게임에 어서오세요    살인 마피아게임   9.69
# 4            가영실장   병원 실장의 일상   9.65
# ..            ...         ...    ...
# 475         날림생활기  날아간 일상을 기록   9.84
# 476   사예의 식이장애 일지    식이장애 이야기   9.76
# 477          성별역전        소꿉친구   9.69
# 478          이상낙원   마법 학원 판타지   9.89
# 479      이 세계 마왕님  인간소녀와 괴물마왕   9.86
#
# [480 rows x 3 columns]
# ['\n', <a class="movie color_b" href="?st=mcode&amp;sword=205027&amp;target=after">데시벨</a>, '\n', <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:60%">별점 - 총 10점 중</span></span><em>6</em>
# </div>, '\n', <br/>, '전제척인 내용이 허술함 하지만 재밌음 \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t', <a class="report" href="#" onclick="report('kimh****', 'hzzkGdC+IK5JeinQCb83wmrD/VdQ3hHIhX+e0Aeg7UA=', '전제척인 내용이 허술함 하지만 재밌음', '18543923', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>, '\n']

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
urlstr = 'http://www.yes24.com/SearchCorner/Search?domain=BOOK&query=python'
r = requests.get(urlstr)
#r.encoding = "utf-8"
bs = BeautifulSoup(r.text, 'html.parser')
bookList = bs.select('a.gd_name')

for bookDom in bookList:
    title.append(bookDom.string)
    link.append(bookDom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)
with open('output/booklink.csv', "wt", encoding="utf-8") as f:
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')
# Out:
# -- 도서 제목 --
# ['혼자 공부하는 파이썬', '혼자 공부하는 머신러닝+딥러닝', 'Do it! 점프 투 파이썬', '만들면서 배우는 파이썬과 40개의 작품들', '1일 1로그 100일 완성 IT 지식', '데이터에듀 빅데이터 분석기사 실기 with Python', '파이썬 머신러닝 완벽 가이드', '밑바닥부터 시작하는 딥러닝 ', '이것이 취업을 위한 코딩 테스트다 with 파이썬 ', '2023 이기적 빅데이터분석기사 실기 기본서', 'Pandas를 이용한 데이터 분석 실습 2/e', '핸즈온 머신러닝', 'Do it! 쉽게 배우는 파이썬 데이터 분석', 'Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편', '밑바닥부터 시작하는 딥러닝 2', '케라스 창시자에게 배우는 딥러닝 개정 2판', '일잘러의 비밀, 엑셀 대신 파이썬으로 업무 자동화하기', 'Do it! 알고리즘 코딩 테스트 - 파이썬 편', '파이썬 알고리즘 인터뷰', '파이썬 클린 코드 2nd Edition', 'OpenCV-Python으로 배우는 영상처리 및 응용', '모두의 데이터 분석 with 파이썬', '모두의 인공지능 기초 수학', 'Do it! 파이썬 생활 프로그래밍']
# -- 도서 링크 URL --
# ['/Product/Goods/109625396', '/Product/Goods/96024871', '/Product/Goods/74419916', '/Product/Goods/107490270', '/Product/Goods/105803863', '/Product/Goods/114655897', '/Product/Goods/108824557', '/Product/Goods/34970929', '/Product/Goods/91433923', '/Product/Goods/114873812', '/Product/Goods/115330064', '/Product/Goods/89959711', '/Product/Goods/108947478', '/Product/Goods/91219874', '/Product/Goods/72173703', '/Product/Goods/112012471', '/Product/Goods/109003861', '/Product/Goods/111686187', '/Product/Goods/91084402', '/Product/Goods/114667254', '/Product/Goods/95785417', '/Product/Goods/72227684', '/Product/Goods/91358533', '/Product/Goods/91437485']

# %% [markdown]
# ### API 별 응답내용 한글처리 방법

# %%
import requests
from bs4 import BeautifulSoup
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
r.encoding = 'utf-8'
html = r.text
print(html)
print("===================================")
bs = BeautifulSoup(html, 'html.parser')
print(bs.prettify())

# %%
import requests
from bs4 import BeautifulSoup
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
html = r.content
html = r.content.decode('utf-8')
print(html)
print("===================================")
bs = BeautifulSoup(html, 'html.parser')
print(bs.prettify())

# %%
import urllib.request
from bs4 import BeautifulSoup
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = urllib.request.urlopen(urlstr)
html = r.read()
html = html.decode('utf-8')
print(html)
print("===================================")
bs = BeautifulSoup(html, 'html.parser')
print(bs.prettify())

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd


titles = list()
summaries = list()
ratings = list()

for page_num in range(1,21):
    url = f"https://comic.naver.com/genre/bestChallenge.nhn?&page={page_num}" 
    req = requests.get(url)
    
    html = req.content.decode("utf-8")
    bs= BeautifulSoup(html, "html.parser")
    
    for info in bs.find_all(class_="challengeInfo"):
        titles.append(info.find(class_="challengeTitle").a.text.strip())
        summaries.append(info.find(class_="summary").text.strip())
        ratings.append(info.find(class_="rating_type").strong.text.strip())
    print(f"{len(titles)}개 추출")
    
naver_comic_dict = { 'title':titles, 'summary' : summaries, 'rating' : ratings }    

df = pd.DataFrame(naver_comic_dict)
display(df)
# Out:
# 24개 추출
# 48개 추출
# 72개 추출
# 96개 추출
# 120개 추출
# 144개 추출
# 168개 추출
# 192개 추출
# 216개 추출
# 240개 추출
# 264개 추출
# 288개 추출
# 312개 추출
# 336개 추출
# 360개 추출
# 384개 추출
# 408개 추출
# 432개 추출
# 456개 추출
# 480개 추출
#             title                          summary rating
# 0         오디네리 피플  우리집, 당신집, 누군가의 집. 그저 평범한 가족이야기!   9.41
# 1            이딴여행                            여행포토툰   9.79
# 2        과학고 생존일지                       과학고에 간 문과생   9.81
# 3          고인물 연애                       15년차 커플 일상   9.81
# 4    마피아게임에 어서오세요                         살인 마피아게임   9.69
# ..            ...                              ...    ...
# 475         날림생활기                       날아간 일상을 기록   9.84
# 476   사예의 식이장애 일지                         식이장애 이야기   9.76
# 477          성별역전                             소꿉친구   9.69
# 478          이상낙원                        마법 학원 판타지   9.89
# 479      이 세계 마왕님                       인간소녀와 괴물마왕   9.86
#
# [480 rows x 3 columns]
