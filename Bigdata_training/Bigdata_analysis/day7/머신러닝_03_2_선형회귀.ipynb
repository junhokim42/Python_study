# %% [markdown]
# # 선형 회귀

# %% [markdown]
# ## k-최근접 이웃의 한계
# - 농어의 무게가 커지게 되면......

# %%
import numpy as np

perch_length = np.array(
    [8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 
     21.0, 21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 
     22.5, 22.7, 23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 
     27.3, 27.5, 27.5, 27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 
     36.5, 36.0, 37.0, 37.0, 39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 
     40.0, 42.0, 43.0, 43.0, 43.5, 44.0]
     )
perch_weight = np.array(
    [5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 
     110.0, 115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 
     130.0, 150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 
     197.0, 218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 
     514.0, 556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 
     820.0, 850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 
     1000.0, 1000.0]
     )

# %%
from sklearn.model_selection import train_test_split

# 훈련 세트와 테스트 세트로 나눕니다
train_input, test_input, train_target, test_target = 
# 훈련 세트와 테스트 세트를 2차원 배열로 바꿉니다

# %%
from sklearn.neighbors import KNeighborsRegressor

# k-최근접 이웃 회귀 모델을 훈련합니다
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %% [markdown]
# - 길이가 50cm인 농어의 무게를 예측

# %%
# Out:
# [1033.33333333]

# %% [markdown]
# - 농어의 길이가 50cm면 무게는 훨씬 많이 나감
#     - 1000g으로 예측한 이유는?

# %%
import matplotlib.pyplot as plt

# %%
# 50cm 농어의 이웃을 구합니다
distances, indexes = 

# 훈련 세트의 산점도를 그립니다
plt.scatter(train_input, train_target)
# 훈련 세트 중에서 이웃 샘플만 다시 그립니다

# 50cm 농어 데이터

plt.show()

# %% [markdown]
# - 전체적으로 길이가 길면 무게가 많이 나가는 모양의 그래프 임
#     - 무게는 모르는 상태로 길이를 기준으로 무게를 찾아보니 저 삼각형 근처의 농어 무게들은 가장 가까운게 45cm근방이고 그 무게들을 평균하니 1033g이 나옴
#         - 새로운 샘플이 훈련 세트의 범위를 벗어나니 선형적인 관계를 반영하지 못하고 엉뚱한 예측을 한 예제임

# %%
# Out:
# 1033.3333333333333

# %% [markdown]
# - 농어의 길이를 더 늘려보자....
#     - 100cm의 농어의 무게는?

# %%
# Out:
# [1033.33333333]

# %% [markdown]
# - 훈련 세트 벗어난 경우 100이나 50이나 모두 1033g으로 예측

# %%
# 100cm 농어의 이웃을 구합니다


# 훈련 세트의 산점도를 그립니다
plt.scatter(train_input, train_target)
# 훈련 세트 중에서 이웃 샘플만 다시 그립니다

# 100cm 농어 데이터

plt.show()

# %% [markdown]
# - 100cm 농어의 이웃을 표시하면 50cm 농어의 이웃과 동일함

# %% [markdown]
# - tip. 머신 러닝 모델은 한번 만들고 끝나지 않는다. 시간이 변하고 환경이 변하면 데이터도 새로 축적되고 새로운 데이터들이 들어오기 때문에 계속해서 최신화를 해 줘야 함.

# %% [markdown]
# ## 선형 회귀
# - 널리 사용되는 대표적인 회귀 알고리즘
#     - 비교적 간단하고 성능이 뛰어남
#     - 특성이 하나인 경우 직선을 학습하는 알고리즘
#         - 특성을 잘 나타내는 직선을 찾아야 한다.

# %% [markdown]
# ## 다음 아래 3개의 이미지에서 그래프를 가장 잘 나타내는 직선은?
# ![image.png](attachment:image.png)
#
# - 첫번째 이미지는 모든 무게를 하나로 예측
# - 두번째 이미지는 길이의 반대로 무게를 예측
# - 세번째 이미지는 길이와 비례하여 무게를 예측 : 세번째 이미지가 가장 그래프를 잘 나타내고 있음
#     - **회귀알고리즘은 세번재 이미지의 직선을 자동으로 찾아내는 알고리즘임**

# %% [markdown]
# - from sklearn.linear_model import LinearRegression
#     - 위 클래스로 구현되어 있음

# %%
from sklearn.linear_model import LinearRegression

# %%
# 선형 회귀 모델 훈련
# Out:
# LinearRegression()

# %%
# 50cm 농어에 대한 예측
# Out:
# [1241.83860323]

# %% [markdown]
# - K-최근접 이웃 알고리즘이랑은 다르게 50CM의 농어의 무게를 더 크게 예측함
# - 어떻게 이 값이 나왔는지 직선을 그려보자
# - 직선을 그리기 위해서는 기울기와 절편이 필요함
#     - 선형 회귀알고리즘은 모델객체의 속성으로 기울기와 절편을 제공함
#         - coef_ : 기울기(계수, 가중치 등으로 불림)
#         - intercept_ : 절편
#      ![image.png](attachment:image.png)

# %%
# Out:
# [39.01714496] -709.0186449535477

# %% [markdown]
# - 농어의 길이 15에서 50까지의 무게를 예측해서 직선을 그린다고 하면
#     - 직선의 두 점은
#         - (15,15X39-709) , (50,50X39-709)

# %%
# 훈련 세트의 산점도를 그립니다

# 15에서 50까지 1차 방정식 그래프를 그립니다

# 50cm 농어 데이터

plt.show()

# %% [markdown]
# - 위 그래프를 보면 무게는 1200 정도로 예측 됨

# %%
# 훈련세트와 테스트세트에 대한 R2 스코어 확인
# Out:
# 0.9398463339976039
# 0.8247503123313558

# %% [markdown]
# ![image.png](attachment:image.png)
# - 훈련세트에 과대적합 되어 있느건지?
#     - 훈련세트의 점수도 그리 높지 않다. 오히려 과소적합되어 있음
#         - 그래프 왼쪽 아래를 보면 15cm의 농어의 무게는 -로 계산하고 있음
#         - **농어의 길이와 무게의 산점도는 일직선이라기보다 왼쪽 위로 조금 구부러진 곡선에 가까움**

# %% [markdown]
# ### 최적의 곡선을 찾아보자
# ![image.png](attachment:image.png)
# - 이차 방정식으로 그래프를 그린다
#     - 길이를 제곱한 항이 훈련세트에 추가되어야 함
#     ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 다항 회귀

# %%
# 훈련세트의 2차항을 데이터에 추가

# %%
# Out:
# (42, 2) (14, 2)

# %% [markdown]
# - 제곱열을 추가했기 때문에 열이 늘어남

# %%
# Out:
# array([[ 384.16,   19.6 ],
#        [ 484.  ,   22.  ],
#        [ 349.69,   18.7 ],
#        [ 302.76,   17.4 ],
#        [1296.  ,   36.  ],
#        [ 625.  ,   25.  ],
#        [1600.  ,   40.  ],
#        [1521.  ,   39.  ],
#        [1849.  ,   43.  ],
#        [ 484.  ,   22.  ]])

# %% [markdown]
# - 특성(제곱열)이 추가되었으므로 다시 학습

# %%
# Out:
# [1573.98423528]

# %%
# Out:
# [  1.01433211 -21.55792498] 116.05021078278259

# %% [markdown]
# ### 아래와 같은 그래프를 학습함
# ![image.png](attachment:image.png)

# %%
# 구간별 직선을 그리기 위해 15에서 49까지 정수 배열을 만듭니다
# 짧은 직선을 이어 그리면 곡선이 됨

# 훈련 세트의 산점도를 그립니다

# 15에서 49까지 2차 방정식 그래프를 그립니다

# 50cm 농어 데이터

plt.show()

# %% [markdown]
# - 단순 선형 회귀모델보다 데이터에 적합한 그래프가 그려짐

# %%
# Out:
# 0.9706807451768623
# 0.9775935108325121

# %% [markdown]
# - 훈련세트와 테스트 점수가 높아짐
#     - 여전히 훈련세트 점수가 높으므로 과소적합이 보임

# %% [markdown]
# - 회귀 모델은 학습데이터의 범위를 벗어나는 범위의 데이터도 예측이 가능

# %% [markdown]
# ### **정리**
# - 아파트가격이 평수에 의해서만 결정된다고 가정할 때
# ![image.png](attachment:image.png)
# - 최적의 회귀 모델
#     - 실제값과 모델 사이의 오류값(잔차) 합이 최소가 되는 모델
#     - 오류 값 합이 최소가 될 수 있는 최적의 회귀 계수를 찾는 것
